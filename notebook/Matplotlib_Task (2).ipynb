# %% [markdown]
# # Matplotlib Task

# %% [markdown]
# ## Create plots using the following data

# %%
import numpy as np
a = np.arange(0,100)
b = a - 5
c = a ** 3 - b ** 2

# %% [markdown]
# ### 1. Import matplotlib.pyplot and set %matplotlib inline

# %%
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### 2. a. Create a figure object
# ### b. Add axes to the figure object passing [0, 0, 1, 1] list as a parameter
# ### c. Create a plot with a as x axis data and b as y axis data
# ### d. Add labels to the plot like on the plot below

# %%
# Out:
# Text(0.5, 1.0, 'title label')

# %%
figure = plt.figure()
axes = figure.add_axes([0, 0, 1, 1])
axes.plot(a, b)
axes.grid()

# %% [markdown]
# ### 3. Create a figure object and add two axes - axes1 and axes2. Pass the following lists as parameters - [0, 0, 1, 1] to axes1 and [0.2, 0.5, 0.2, 0.3] to axes2

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0, 0, 1, 1])
axes2 = figure1.add_axes([0.2, 0.5, 0.2, 0.3])

# %% [markdown]
# ### 4. Create plots with a as x axis data and b as y axis data on axes1 and with b as x axis data and c as y axis data on axes2 for the previos figure object and show the plot by calling figure variable

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0, 0, 1, 1])
axes2 = figure1.add_axes([0.2, 0.5, 0.2, 0.3])

axes1.plot(a,b)
axes2.plot(a,c)

# %% [markdown]
# ### 5. a. Create a figure object and add two axes - axes1 and axes2. Pass the following lists as parameters - [0, 0, 1, 1] to axes1 and [0.2, 0.5, 0.3, 0.4] to axes2
# ### b. Create plots using a, b, c arrays to match the image below. Add limits to the plots - x limit equals (20, 60) and y limit equals (10, 70) for axes1 and x limit equals (20, 60) and y limit equals (10000, 70000) for axes2

# %%
figure1 = plt.figure()
axes1 = figure1.add_axes([0, 0, 1, 1], figsize=(7,3), dpi=100)
axes2 = figure1.add_axes([0.2, 0.5, 0.2, 0.3])

axes = figure.add_axes([0,0,1,1])

axes1.plot(a,b)
axes2.plot(a,c)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [14], in <cell line: 2>()
#       1 figure1 = plt.figure()
# ----> 2 axes1 = figure1.add_axes([0, 0, 1, 1], figsize=(7,3), dpi=100)
#       3 axes2 = figure1.add_axes([0.2, 0.5, 0.2, 0.3])
#       5 axes = figure.add_axes([0,0,1,1])
#
# File ~\anaconda3\lib\site-packages\matplotlib\figure.py:642, in FigureBase.add_axes(self, *args, **kwargs)
#     638     projection_class, pkw = self._process_projection_requirements(
#     639         *args, **kwargs)
#     641     # create the new axes using the axes class given
# --> 642     a = projection_class(self, rect, **pkw)
#     643     key = (projection_class, pkw)
#     644 return self._add_axes_internal(a, key)
#
# File ~\anaconda3\lib\site-packages\matplotlib\_api\deprecation.py:456, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     450 if len(args) > name_idx:
#     451     warn_deprecated(
#     452         since, message="Passing the %(name)s %(obj_type)s "
#     453         "positionally is deprecated since Matplotlib %(since)s; the "
#     454         "parameter will become keyword-only %(removal)s.",
#     455         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 456 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:646, in _AxesBase.__init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, box_aspect, **kwargs)
#     643 if yscale:
#     644     self.set_yscale(yscale)
# --> 646 self.update(kwargs)
#     648 for name, axis in self._get_axis_map().items():
#     649     axis.callbacks._pickled_cids.add(
#     650         axis.callbacks.connect(
#     651             'units', self._unit_change_handler(name)))
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1062             func = getattr(self, f"set_{k}", None)
#    1063             if not callable(func):
# -> 1064                 raise AttributeError(f"{type(self).__name__!r} object "
#    1065                                      f"has no property {k!r}")
#    1066             ret.append(func(v))
#    1067 if ret:
#
# AttributeError: 'Axes' object has no property 'figsize'

# %% [markdown]
# ### 6. a. Create a figure object with 2 axes in 1 row with the help of subplots() method
# ### b. Resize both axes - set 11 inches to width and 3 inches to height
# ### c. Create the plot on the first axes with c as x axis data and a as y axis data
# ### d. Create the plot on the second axes with c as x axis data and b as y axis data
# ### d. Change the appearance of plot lines somehow. Play with colors, width and styles
