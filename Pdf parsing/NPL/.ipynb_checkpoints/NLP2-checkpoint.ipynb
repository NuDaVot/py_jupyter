# %%
import pandas as pd

# %%
df =pd.read_csv("dataset.csv")

# %%
df.head()
# Out:
#    Unnamed: 0    namecompany                                     description  \
# 0           0  Timeweb Cloud  Облачная платформа для разработчиков и бизнеса
# 1           1           OTUS            Цифровые навыки от ведущих экспертов
# 2           2  Онлайн Патент                       Ваш личный патентный офис
# 3           3           OTUS            Цифровые навыки от ведущих экспертов
# 4           4             VK                  Технологии, которые объединяют
#
#     rating                                           activity date_publish  \
# 0  1572.77      Веб-разработка, Домены и хостинг, Веб-сервисы   2023-03-27
# 1   795.43  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 2   220.74                Консалтинг и поддержка, Веб-сервисы   2023-03-27
# 3   795.43  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 4   568.63  Мобильные технологии, Веб-сервисы, Игры и разв...   2023-03-27
#
#                                         text_article
# 0  В своём блоге я рассмотрел устройство и назнач...
# 1  Автор статьи: Роман КозловРуководитель курса B...
# 2  Рынок биологически активных добавок(БАД) с каж...
# 3  Автор статьи: Александр КолесниковВирусный ана...
# 4  Всем привет! Меня зовут Артём Пузанков, я DevS...

# %%
df.shape
# Out:
# (438, 7)

# %%
df = df.drop(["Unnamed: 0"], axis=1)

# %%
df.head()
# Out:
#      namecompany                                     description   rating  \
# 0  Timeweb Cloud  Облачная платформа для разработчиков и бизнеса  1572.77
# 1           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 2  Онлайн Патент                       Ваш личный патентный офис   220.74
# 3           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 4             VK                  Технологии, которые объединяют   568.63
#
#                                             activity date_publish  \
# 0      Веб-разработка, Домены и хостинг, Веб-сервисы   2023-03-27
# 1  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 2                Консалтинг и поддержка, Веб-сервисы   2023-03-27
# 3  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 4  Мобильные технологии, Веб-сервисы, Игры и разв...   2023-03-27
#
#                                         text_article
# 0  В своём блоге я рассмотрел устройство и назнач...
# 1  Автор статьи: Роман КозловРуководитель курса B...
# 2  Рынок биологически активных добавок(БАД) с каж...
# 3  Автор статьи: Александр КолесниковВирусный ана...
# 4  Всем привет! Меня зовут Артём Пузанков, я DevS...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 438 entries, 0 to 437
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   namecompany   438 non-null    object
#  1   description   438 non-null    object
#  2   rating        438 non-null    float64
#  3   activity      433 non-null    object
#  4   date_publish  438 non-null    object
#  5   text_article  438 non-null    object
# dtypes: float64(1), object(5)
# memory usage: 20.7+ KB

# %% [markdown]
# ### Предварительная обработка данных

# %% [markdown]
# 1. Перевод всех букв в тексте в нижний регистр
# 2. Удалить пунктуацию
# 3. Токенизация по словам
# 4. Удаление стоп слов
# 5. Стемминг
# 6. Лемматизация

# %%
import string

# %%
string.punctuation
# Out:
# '!"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~'

# %%
def remove_punctuation(text):
    return ''.join([ch for ch in text if ch not in string.punctuation])

# %%
df['text_article'][0]
# Out:
# 'В своём блоге я рассмотрел устройство и назначение почти всех контроллеров Norvi, обойдены вниманием оказались только контроллеры линейки GSM, имеющие соответствующие модули на своём борту.Как вы понимаете, наличие GSM модуля является существенным дополнением и значительно расширяет возможности контроллера: можно посылать и принимать информационные и управляющие SMS, можно организовать резервный, независимый от вашей IoT инфраструктуры канал связи и т.\xa0д.В этой статье я рассмотрю модель NORVI GSM AE02-V, которая кроме ESP32 и GSM модуля содержит цифровые и аналоговые входы, интерфейс RS485 и прочие возможности, что делает этот контроллер интересным решением для создания ваших проектов по автоматизации.❯Семейство NORVI GSMКонтроллеры линейки NORVI GSM имеют в качестве ядра модуль ESP32-WROOM-32 (Wi-Fi, Bluetooth, 4 МБ EEPROM и т. д.), что позволяет решать довольно тяжёлые вычислительные задачи, поддерживать беспроводную связь и полноценный веб-интерфейс, работать с шифрованием данных и т.\xa0д.Большинство моделей контроллеров этой линейки имеют GSM модуль, дисплей, кнопки управления на передней панели корпуса, межблочный интерфейс и цифровые опторазвязанные входы (DI). Остальные характеристики отличаются, составить представление о них можно по следующей таблице:Модель AE02-V, имеющаяся в моём распоряжении, выделена серым фоном.В моём распоряжении имеется начальная, но довольно функциональная модель AE02-V. Судя по вышеприведённой таблице, взятой из официальной документации Norvi, эта модель должна иметь 2 транзисторных выхода, но на самом деле они отсутствуют в реальном контроллере. Что это — ошибка в документации или выходы просто «забыли» распаять на плате — сказать трудно. Судя по отсутствию маркировки выходов на корпусе устройства, это, скорее всего, ошибка в документации.Все контроллеры этой линейки содержат GSM модуль, это либо более простой SIM800C, либо более продвинутый LTE модуль QUECTEL EC21-G. В моём случае это привычный нам SIM800C. Штыревая антенна на корпусе AE02-V — это антенна GSM модуля.❯Компоненты и характеристикиЧем же в этот раз нас порадовала Norvi? Давайте познакомимся со списком компонентов, находящихся на борту NORVI GSM AE02-V.Контроллер: ESP32-WROOM-32GSM модуль SIM800CВнешняя GSM антеннаРазъём для SIM карт8 цифровых входов8 светодиодов входов4 аналоговых входа (0-10 В)Интерфейс RS485Дисплей (SSD1306)3 кнопки управления на передней панелиМежблочный интерфейсMicro-USB разъём для программированияКнопка ResetИндикатор наличия питанияНапряжение питания: 24 ВВ целом можно сказать, что это довольно гармоничная и сбалансированная модель для несложных проектов. Если бы на борту присутствовали транзисторные выходы, заявленные в документации, то всё было бы совсем хорошо.Но учитывая, что NORVI GSM AE02-V имеет межблочный интерфейс (UART, I2C), функционал контроллера можно значительно расширить, в соответствии с требованиями вашего проекта.Картину дополняют традиционные для Norvi отличный дизайн корпуса, дисплей, кнопки управления и светодиодные индикаторы — с таким контроллером очень приятно работать и он точно не испортит внешний вид вашего щитка автоматики.❯Разбираем контроллерЕсть у контроллеров Norvi одна неприятная родовая черта — практически все модели, за редкими исключениями, очень трудно разбираются. Можно сказать, что они вообще не предназначены для разборки — в процессе вскрытия корпуса и извлечения из него контроллера приходится сильно гнуть пластмассу, рискуя её сломать и подвергать механическим нагрузкам сами платы контроллера.Причём разобрать контроллер Norvi трудно, даже если ты много раз это делал и точно знаешь, что делаешь. Например, во время разборки NORVI GSM AE02-V и извлечения его платы из «поддона» мной была повреждена печатная дорожка у края платы. И тут выбор не велик: либо риск сломать пластмассу корпуса, либо риск повредить плату контроллера.(А ведь существует множество контроллеров, которые разбираются легко и просто.)В случае контроллеров Norvi главными виновниками проблем с ра ...

# %%
t = remove_punctuation(df['text_article'][0].lower())

# %%
t
# Out:
# 'в своём блоге я рассмотрел устройство и назначение почти всех контроллеров norvi обойдены вниманием оказались только контроллеры линейки gsm имеющие соответствующие модули на своём бортукак вы понимаете наличие gsm модуля является существенным дополнением и значительно расширяет возможности контроллера можно посылать и принимать информационные и управляющие sms можно организовать резервный независимый от вашей iot инфраструктуры канал связи и т\xa0дв этой статье я рассмотрю модель norvi gsm ae02v которая кроме esp32 и gsm модуля содержит цифровые и аналоговые входы интерфейс rs485 и прочие возможности что делает этот контроллер интересным решением для создания ваших проектов по автоматизации❯семейство norvi gsmконтроллеры линейки norvi gsm имеют в качестве ядра модуль esp32wroom32 wifi bluetooth 4 мб eeprom и т д что позволяет решать довольно тяжёлые вычислительные задачи поддерживать беспроводную связь и полноценный вебинтерфейс работать с шифрованием данных и т\xa0дбольшинство моделей контроллеров этой линейки имеют gsm модуль дисплей кнопки управления на передней панели корпуса межблочный интерфейс и цифровые опторазвязанные входы di остальные характеристики отличаются составить представление о них можно по следующей таблицемодель ae02v имеющаяся в моём распоряжении выделена серым фономв моём распоряжении имеется начальная но довольно функциональная модель ae02v судя по вышеприведённой таблице взятой из официальной документации norvi эта модель должна иметь 2 транзисторных выхода но на самом деле они отсутствуют в реальном контроллере что это — ошибка в документации или выходы просто «забыли» распаять на плате — сказать трудно судя по отсутствию маркировки выходов на корпусе устройства это скорее всего ошибка в документациивсе контроллеры этой линейки содержат gsm модуль это либо более простой sim800c либо более продвинутый lte модуль quectel ec21g в моём случае это привычный нам sim800c штыревая антенна на корпусе ae02v — это антенна gsm модуля❯компоненты и характеристикичем же в этот раз нас порадовала norvi давайте познакомимся со списком компонентов находящихся на борту norvi gsm ae02vконтроллер esp32wroom32gsm модуль sim800cвнешняя gsm антеннаразъём для sim карт8 цифровых входов8 светодиодов входов4 аналоговых входа 010 винтерфейс rs485дисплей ssd13063 кнопки управления на передней панелимежблочный интерфейсmicrousb разъём для программированиякнопка resetиндикатор наличия питаниянапряжение питания 24 вв целом можно сказать что это довольно гармоничная и сбалансированная модель для несложных проектов если бы на борту присутствовали транзисторные выходы заявленные в документации то всё было бы совсем хорошоно учитывая что norvi gsm ae02v имеет межблочный интерфейс uart i2c функционал контроллера можно значительно расширить в соответствии с требованиями вашего проектакартину дополняют традиционные для norvi отличный дизайн корпуса дисплей кнопки управления и светодиодные индикаторы — с таким контроллером очень приятно работать и он точно не испортит внешний вид вашего щитка автоматики❯разбираем контроллересть у контроллеров norvi одна неприятная родовая черта — практически все модели за редкими исключениями очень трудно разбираются можно сказать что они вообще не предназначены для разборки — в процессе вскрытия корпуса и извлечения из него контроллера приходится сильно гнуть пластмассу рискуя её сломать и подвергать механическим нагрузкам сами платы контроллерапричём разобрать контроллер norvi трудно даже если ты много раз это делал и точно знаешь что делаешь например во время разборки norvi gsm ae02v и извлечения его платы из «поддона» мной была повреждена печатная дорожка у края платы и тут выбор не велик либо риск сломать пластмассу корпуса либо риск повредить плату контроллераа ведь существует множество контроллеров которые разбираются легко и простов случае контроллеров norvi главными виновниками проблем с разборкой и сборкой являются боковой разъём расширения и слишком мощные фиксаторы платы на нижней крышке корпус ...

# %%
def remove_numbers(text):
    return ''.join([i if not i.isdigit() else ' ' for i in text])

# %%
t = remove_numbers(t)

# %%
def remove_notalpha(text):
    return ''.join([i if i.isalpha() else ' ' for i in text])

# %%
t = remove_notalpha(t)

# %%
import re
def remove_space(text):
    return re.sub(r'\s+',' ', text, flags=re.I)

# %%
t = remove_space(t)

# %%
def remove_latin(text):
    return re.sub('[a-z]','', text, flags=re.I)

# %%
t = remove_latin(t)

# %%
st = '❯\xa0'
def remove_othersymbol(text):
    return ''.join([ch if ch not in st else ' ' for ch in text])

# %%
t = remove_othersymbol(t)

# %%
t
# Out:
# 'в своём блоге я рассмотрел устройство и назначение почти всех контроллеров  обойдены вниманием оказались только контроллеры линейки  имеющие соответствующие модули на своём бортукак вы понимаете наличие  модуля является существенным дополнением и значительно расширяет возможности контроллера можно посылать и принимать информационные и управляющие  можно организовать резервный независимый от вашей  инфраструктуры канал связи и т дв этой статье я рассмотрю модель     которая кроме  и  модуля содержит цифровые и аналоговые входы интерфейс  и прочие возможности что делает этот контроллер интересным решением для создания ваших проектов по автоматизации семейство  контроллеры линейки   имеют в качестве ядра модуль     мб  и т д что позволяет решать довольно тяжёлые вычислительные задачи поддерживать беспроводную связь и полноценный вебинтерфейс работать с шифрованием данных и т дбольшинство моделей контроллеров этой линейки имеют  модуль дисплей кнопки управления на передней панели корпуса межблочный интерфейс и цифровые опторазвязанные входы  остальные характеристики отличаются составить представление о них можно по следующей таблицемодель   имеющаяся в моём распоряжении выделена серым фономв моём распоряжении имеется начальная но довольно функциональная модель   судя по вышеприведённой таблице взятой из официальной документации  эта модель должна иметь транзисторных выхода но на самом деле они отсутствуют в реальном контроллере что это ошибка в документации или выходы просто забыли распаять на плате сказать трудно судя по отсутствию маркировки выходов на корпусе устройства это скорее всего ошибка в документациивсе контроллеры этой линейки содержат  модуль это либо более простой   либо более продвинутый  модуль    в моём случае это привычный нам   штыревая антенна на корпусе   это антенна  модуля компоненты и характеристикичем же в этот раз нас порадовала  давайте познакомимся со списком компонентов находящихся на борту    контроллер    модуль  внешняя  антеннаразъём для  карт цифровых входов светодиодов входов аналоговых входа винтерфейс  дисплей  кнопки управления на передней панелимежблочный интерфейс разъём для программированиякнопка индикатор наличия питаниянапряжение питания вв целом можно сказать что это довольно гармоничная и сбалансированная модель для несложных проектов если бы на борту присутствовали транзисторные выходы заявленные в документации то всё было бы совсем хорошоно учитывая что     имеет межблочный интерфейс    функционал контроллера можно значительно расширить в соответствии с требованиями вашего проектакартину дополняют традиционные для  отличный дизайн корпуса дисплей кнопки управления и светодиодные индикаторы с таким контроллером очень приятно работать и он точно не испортит внешний вид вашего щитка автоматики разбираем контроллересть у контроллеров  одна неприятная родовая черта практически все модели за редкими исключениями очень трудно разбираются можно сказать что они вообще не предназначены для разборки в процессе вскрытия корпуса и извлечения из него контроллера приходится сильно гнуть пластмассу рискуя её сломать и подвергать механическим нагрузкам сами платы контроллерапричём разобрать контроллер  трудно даже если ты много раз это делал и точно знаешь что делаешь например во время разборки     и извлечения его платы из поддона мной была повреждена печатная дорожка у края платы и тут выбор не велик либо риск сломать пластмассу корпуса либо риск повредить плату контроллераа ведь существует множество контроллеров которые разбираются легко и простов случае контроллеров  главными виновниками проблем с разборкой и сборкой являются боковой разъём расширения и слишком мощные фиксаторы платы на нижней крышке корпуса схемотехникавнутреннее устройство   также типично для контроллеров  это всё те же две платы соединённые между собой двумя стойками по штырьков соединения неразъёмные и если вам захочется модернизировать     то без значительных усилий и хирургических вмешательств это сделать не получитсяахтунг ...

# %%
import nltk
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\МОиБД\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %%
stopword = stopwords.words("english")

# %%
stopword
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
stopword = nltk.corpus.stopwords.words('russian')

# %%
stopword
# Out:
# ['и',
#  'в',
#  'во',
#  'не',
#  'что',
#  'он',
#  'на',
#  'я',
#  'с',
#  'со',
#  'как',
#  'а',
#  'то',
#  'все',
#  'она',
#  'так',
#  'его',
#  'но',
#  'да',
#  'ты',
#  'к',
#  'у',
#  'же',
#  'вы',
#  'за',
#  'бы',
#  'по',
#  'только',
#  'ее',
#  'мне',
#  'было',
#  'вот',
#  'от',
#  'меня',
#  'еще',
#  'нет',
#  'о',
#  'из',
#  'ему',
#  'теперь',
#  'когда',
#  'даже',
#  'ну',
#  'вдруг',
#  'ли',
#  'если',
#  'уже',
#  'или',
#  'ни',
#  'быть',
#  'был',
#  'него',
#  'до',
#  'вас',
#  'нибудь',
#  'опять',
#  'уж',
#  'вам',
#  'ведь',
#  'там',
#  'потом',
#  'себя',
#  'ничего',
#  'ей',
#  'может',
#  'они',
#  'тут',
#  'где',
#  'есть',
#  'надо',
#  'ней',
#  'для',
#  'мы',
#  'тебя',
#  'их',
#  'чем',
#  'была',
#  'сам',
#  'чтоб',
#  'без',
#  'будто',
#  'чего',
#  'раз',
#  'тоже',
#  'себе',
#  'под',
#  'будет',
#  'ж',
#  'тогда',
#  'кто',
#  'этот',
#  'того',
#  'потому',
#  'этого',
#  'какой',
#  'совсем',
#  'ним',
#  'здесь',
#  'этом',
#  'один',
#  'почти',
#  'мой',
#  'тем',
#  'чтобы',
#  'нее',
#  'сейчас',
#  'были',
#  'куда',
#  'зачем',
#  'всех',
#  'никогда',
#  'можно',
#  'при',
#  'наконец',
#  'два',
#  'об',
#  'другой',
#  'хоть',
#  'после',
#  'над',
#  'больше',
#  'тот',
#  'через',
#  'эти',
#  'нас',
#  'про',
#  'всего',
#  'них',
#  'какая',
#  'много',
#  'разве',
#  'три',
#  'эту',
#  'моя',
#  'впрочем',
#  'хорошо',
#  'свою',
#  'этой',
#  'перед',
#  'иногда',
#  'лучше',
#  'чуть',
#  'том',
#  'нельзя',
#  'такой',
#  'им',
#  'более',
#  'всегда',
#  'конечно',
#  'всю',
#  'между']

# %%
def remove_stopwords(text):
    return [word for word in text if word not in stopword]

# %%
from nltk.tokenize import word_tokenize

# %%
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
def tokenize(text):
    t = word_tokenize(text)
    return [token for token in t if token not in stopword]

# %%
nltk.download('word_tokenize')
# Out:
# [nltk_data] Error loading word_tokenize: Package 'word_tokenize' not
# [nltk_data]     found in index
# False

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\МОиБД\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
word_tokenize(t)
# Out:
# ['в',
#  'своём',
#  'блоге',
#  'я',
#  'рассмотрел',
#  'устройство',
#  'и',
#  'назначение',
#  'почти',
#  'всех',
#  'контроллеров',
#  'обойдены',
#  'вниманием',
#  'оказались',
#  'только',
#  'контроллеры',
#  'линейки',
#  'имеющие',
#  'соответствующие',
#  'модули',
#  'на',
#  'своём',
#  'бортукак',
#  'вы',
#  'понимаете',
#  'наличие',
#  'модуля',
#  'является',
#  'существенным',
#  'дополнением',
#  'и',
#  'значительно',
#  'расширяет',
#  'возможности',
#  'контроллера',
#  'можно',
#  'посылать',
#  'и',
#  'принимать',
#  'информационные',
#  'и',
#  'управляющие',
#  'можно',
#  'организовать',
#  'резервный',
#  'независимый',
#  'от',
#  'вашей',
#  'инфраструктуры',
#  'канал',
#  'связи',
#  'и',
#  'т',
#  'дв',
#  'этой',
#  'статье',
#  'я',
#  'рассмотрю',
#  'модель',
#  'которая',
#  'кроме',
#  'и',
#  'модуля',
#  'содержит',
#  'цифровые',
#  'и',
#  'аналоговые',
#  'входы',
#  'интерфейс',
#  'и',
#  'прочие',
#  'возможности',
#  'что',
#  'делает',
#  'этот',
#  'контроллер',
#  'интересным',
#  'решением',
#  'для',
#  'создания',
#  'ваших',
#  'проектов',
#  'по',
#  'автоматизации',
#  'семейство',
#  'контроллеры',
#  'линейки',
#  'имеют',
#  'в',
#  'качестве',
#  'ядра',
#  'модуль',
#  'мб',
#  'и',
#  'т',
#  'д',
#  'что',
#  'позволяет',
#  'решать',
#  'довольно',
#  'тяжёлые',
#  'вычислительные',
#  'задачи',
#  'поддерживать',
#  'беспроводную',
#  'связь',
#  'и',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'с',
#  'шифрованием',
#  'данных',
#  'и',
#  'т',
#  'дбольшинство',
#  'моделей',
#  'контроллеров',
#  'этой',
#  'линейки',
#  'имеют',
#  'модуль',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'на',
#  'передней',
#  'панели',
#  'корпуса',
#  'межблочный',
#  'интерфейс',
#  'и',
#  'цифровые',
#  'опторазвязанные',
#  'входы',
#  'остальные',
#  'характеристики',
#  'отличаются',
#  'составить',
#  'представление',
#  'о',
#  'них',
#  'можно',
#  'по',
#  'следующей',
#  'таблицемодель',
#  'имеющаяся',
#  'в',
#  'моём',
#  'распоряжении',
#  'выделена',
#  'серым',
#  'фономв',
#  'моём',
#  'распоряжении',
#  'имеется',
#  'начальная',
#  'но',
#  'довольно',
#  'функциональная',
#  'модель',
#  'судя',
#  'по',
#  'вышеприведённой',
#  'таблице',
#  'взятой',
#  'из',
#  'официальной',
#  'документации',
#  'эта',
#  'модель',
#  'должна',
#  'иметь',
#  'транзисторных',
#  'выхода',
#  'но',
#  'на',
#  'самом',
#  'деле',
#  'они',
#  'отсутствуют',
#  'в',
#  'реальном',
#  'контроллере',
#  'что',
#  'это',
#  'ошибка',
#  'в',
#  'документации',
#  'или',
#  'выходы',
#  'просто',
#  'забыли',
#  'распаять',
#  'на',
#  'плате',
#  'сказать',
#  'трудно',
#  'судя',
#  'по',
#  'отсутствию',
#  'маркировки',
#  'выходов',
#  'на',
#  'корпусе',
#  'устройства',
#  'это',
#  'скорее',
#  'всего',
#  'ошибка',
#  'в',
#  'документациивсе',
#  'контроллеры',
#  'этой',
#  'линейки',
#  'содержат',
#  'модуль',
#  'это',
#  'либо',
#  'более',
#  'простой',
#  'либо',
#  'более',
#  'продвинутый',
#  'модуль',
#  'в',
#  'моём',
#  'случае',
#  'это',
#  'привычный',
#  'нам',
#  'штыревая',
#  'антенна',
#  'на',
#  'корпусе',
#  'это',
#  'антенна',
#  'модуля',
#  'компоненты',
#  'и',
#  'характеристикичем',
#  'же',
#  'в',
#  'этот',
#  'раз',
#  'нас',
#  'порадовала',
#  'давайте',
#  'познакомимся',
#  'со',
#  'списком',
#  'компонентов',
#  'находящихся',
#  'на',
#  'борту',
#  'контроллер',
#  'модуль',
#  'внешняя',
#  'антеннаразъём',
#  'для',
#  'карт',
#  'цифровых',
#  'входов',
#  'светодиодов',
#  'входов',
#  'аналоговых',
#  'входа',
#  'винтерфейс',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'на',
#  'передней',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'для',
#  'программированиякнопка',
#  'индикатор',
#  'наличия',
#  'питаниянапряжение',
#  'питания',
#  'вв',
#  'целом',
#  'можно',
#  'сказать',
#  'что',
#  'это',
#  'довольно',
#  'гармоничная',
#  'и',
#  'сбалансированная',
#  'модель',
#  'для',
#  'несложных',
#  'проектов',
#  'если',
#  'бы',
#  'на',
#  'борту',
#  'присутствовали',
#  'транзисторные',
#  'выходы',
#  'заявленные',
#  'в',
#  'документации',
#  'то',
#  'всё',
#  'было',
#  'бы',
#  'совсем',
#  'хорошоно',
#  'учитывая',
#  'что',
#  'имеет',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллера',
#  'можно',
#  'значительно',
#  'расширить',
#  'в',
#  'соответствии',
#  'с',
#  'требованиями',
#  'вашего',
#  'проектакартину',
#  'дополняют',
#  'традиционные',
#  'для',
#  'отличный',
#  'дизайн',
#  'корпуса',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'и',
#  'светодиодные',
#  'индикаторы',
#  'с',
#  'таким',
#  'контроллером',
#  'очень',
#  'приятно',
#  'работать',
#  'и',
#  'он',
#  'точно',
#  'не',
#  'испортит',
#  'внешний',
#  'вид',
#  'вашего',
#  'щитка',
#  'автоматики',
#  'разбираем',
#  'контроллересть',
#  'у',
#  'контроллеров',
#  'одна',
#  'неприятная',
#  'родовая',
#  'черта',
#  'практически',
#  'все',
#  'модели',
#  'за',
#  'редкими',
#  'исключениями',
#  'очень',
#  'трудно',
#  'разбираются',
#  'можно',
#  'сказать',
#  'что',
#  'они',
#  'вообще',
#  'не',
#  'предназначены',
#  'для',
#  'разборки',
#  'в',
#  'процессе',
#  'вскрытия',
#  'корпуса',
#  'и',
#  'извлечения',
#  'из',
#  'него',
#  'контроллера',
#  'приходится',
#  'сильно',
#  'гнуть',
#  'пластмассу',
#  'рискуя',
#  'её',
#  'сломать',
#  'и',
#  'подвергать',
#  'механическим',
#  'нагрузкам',
#  'сами',
#  'платы',
#  'контроллерапричём',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'даже',
#  'если',
#  'ты',
#  'много',
#  'раз',
#  'это',
#  'делал',
#  'и',
#  'точно',
#  'знаешь',
#  'что',
#  'делаешь',
#  'например',
#  'во',
#  'время',
#  'разборки',
#  'и',
#  'извлечения',
#  'его',
#  'платы',
#  'из',
#  'поддона',
#  'мной',
#  'была',
#  'повреждена',
#  'печатная',
#  'дорожка',
#  'у',
#  'края',
#  'платы',
#  'и',
#  'тут',
#  'выбор',
#  'не',
#  'велик',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмассу',
#  'корпуса',
#  'либо',
#  'риск',
#  'повредить',
#  'плату',
#  'контроллераа',
#  'ведь',
#  'существует',
#  'множество',
#  'контроллеров',
#  'которые',
#  'разбираются',
#  'легко',
#  'и',
#  'простов',
#  'случае',
#  'контроллеров',
#  'главными',
#  'виновниками',
#  'проблем',
#  'с',
#  'разборкой',
#  'и',
#  'сборкой',
#  'являются',
#  'боковой',
#  'разъём',
#  'расширения',
#  'и',
#  'слишком',
#  'мощные',
#  'фиксаторы',
#  'платы',
#  'на',
#  'нижней',
#  'крышке',
#  'корпуса',
#  'схемотехникавнутреннее',
#  'устройство',
#  'также',
#  'типично',
#  'для',
#  'контроллеров',
#  'это',
#  'всё',
#  'те',
#  'же',
#  'две',
#  'платы',
#  'соединённые',
#  'между',
#  'собой',
#  'двумя',
#  'стойками',
#  'по',
#  'штырьков',
#  'соединения',
#  'неразъёмные',
#  'и',
#  'если',
#  'вам',
#  'захочется',
#  'модернизировать',
#  'то',
#  'без',
#  'значительных',
#  'усилий',
#  'и',
#  'хирургических',
#  'вмешательств',
#  'это',
#  'сделать',
#  'не',
#  'получитсяахтунг',
#  'из',
#  'обзора',
#  'в',
#  'обзор',
#  'я',
#  'вынужден',
#  'упоминать',
#  'об',
#  'ещё',
#  'одной',
#  'родовой',
#  'проблеме',
#  'качестве',
#  'её',
#  'документации',
#  'эта',
#  'документация',
#  'просто',
#  'ужасна',
#  'одни',
#  'её',
#  'части',
#  'противоречат',
#  'другим',
#  'документация',
#  'противоречит',
#  'надписям',
#  'на',
#  'корпусе',
#  'контроллера',
#  'и',
#  'все',
#  'вместе',
#  'они',
#  'противоречат',
#  'тому',
#  'что',
#  'есть',
#  'реально',
#  'в',
#  'железе',
#  'но',
#  'что',
#  'удивительно',
#  'при',
#  'этом',
#  'само',
#  'железо',
#  'вполне',
#  'адекватное',
#  'и',
#  'нормально',
#  'работаетвсе',
#  'данные',
#  'по',
#  'компонентам',
#  'контактам',
#  'распиновкам',
#  'и',
#  'т',
#  'д',
#  'для',
#  'этого',
#  'обзора',
#  'мне',
#  'приходилось',
#  'проверять',
#  'и',
#  'перепроверять',
#  'с',
#  'лупой',
#  'и',
#  'тестером',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'к',
#  'на',
#  'основании',
#  'данных',
#  'из',
#  'официальной',
#  'документации',
#  'категорически',
#  'не',
#  'рекомендуется',
#  'пользуйтесь',
#  'проверенной',
#  'информацией',
#  'из',
#  'этой',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контактов',
#  'и',
#  'расположение',
#  'индикаторов',
#  'модификации',
#  'платы',
#  'контроллераплаты',
#  'контроллера',
#  'соединены',
#  'между',
#  'собой',
#  'двумя',
#  'группами',
#  'контактов',
#  'и',
#  'каждая',
#  'группа',
#  'содержит',
#  'по',
#  'контактов',
#  'сами',
#  'контакты',
#  'сделаны',
#  'неразъёмными',
#  'разобрать',
#  'контроллер',
#  'можно',
#  'только',
#  'выпаивая',
#  'соединяющие',
#  'платы',
#  'перемычки',
#  'штырьки',
#  'нижняя',
#  'плата',
#  'содержит',
#  'колодки',
#  'для',
#  'подключения',
#  'цифровых',
#  'и',
#  'аналоговых',
#  'входов',
#  'питания',
#  'контроллера',
#  'в',
#  'а',
#  'также',
#  'разъём',
#  'интерфейса',
#  'на',
#  'этой',
#  'же',
#  'плате',
#  'находятся',
#  'электронные',
#  'компоненты',
#  'соответствующих',
#  'подсистемверхняя',
#  'плата',
#  'содержит',
#  'микроконтроллер',
#  'модуль',
#  'разъёмы',
#  'для',
#  'подключения',
#  'карты',
#  'и',
#  'выносной',
#  'антенны',
#  'межблочный',
#  'интерфейс',
#  'подсистему',
#  'на',
#  'чипе',
#  'дисплей',
#  'управляющие',
#  'кнопки',
#  'индикаторные',
#  'светодиоды',
#  'и',
#  'прочие',
#  'элементыпитаниеподсистема',
#  'питания',
#  'состоит',
#  'из',
#  'импульсного',
#  'понижающего',
#  'регулятора',
#  'напряжения',
#  'на',
#  'в',
#  'и',
#  'линейного',
#  'регулятора',
#  'контроллер',
#  'рассчитан',
#  'на',
#  'входное',
#  'напряжение',
#  'в',
#  'но',
#  'работает',
#  'и',
#  'от',
#  'меньшего',
#  'напряжениявид',
#  'на',
#  'элементы',
#  'подсистемы',
#  'питания',
#  'индуктивность',
#  'диод',
#  'фильтрующие',
#  'конденсаторы',
#  'и',
#  'прочие',
#  'элементы',
#  'микросхема',
#  'преобразователя',
#  'спряталась',
#  'за',
#  'конденсатором',
#  'и',
#  'индуктивностью',
#  'формирующий',
#  'напряжение',
#  'в',
#  'находится',
#  'на',
#  'верхней',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'можно',
#  'от',
#  'разъёма',
#  'но',
#  'в',
#  'данном',
#  'случае',
#  'на',
#  'плате',
#  'установлен',
#  'модуль',
#  'с',
#  'большим',
#  'пиковым',
#  'потреблением',
#  'тока',
#  'поэтому',
#  'полноценным',
#  'питанием',
#  'через',
#  'контакты',
#  'колодок',
#  'лучше',
#  'не',
#  'пренебрегатьядро',
#  'в',
#  'качестве',
#  'ядра',
#  'контроллер',
#  'использует',
#  'популярный',
#  'модуль',
#  'который',
#  'располагается',
#  'на',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'там',
#  'же',
#  'находится',
#  'линейный',
#  'регулятор',
#  'формирующий',
#  'напряжение',
#  'для',
#  'его',
#  'питаниядля',
#  'подключения',
#  'к',
#  'компьютеру',
#  'и',
#  'программирования',
#  'на',
#  'верхней',
#  'плате',
#  'присутствует',
#  'разъём',
#  'и',
#  'микросхема',
#  'преобразователя',
#  'а',
#  'также',
#  'прочие',
#  'элементы',
#  'и',
#  'кнопка',
#  'в',
#  'корпусе',
#  'рядом',
#  'с',
#  'разъём',
#  'есть',
#  'отверстие',
#  'для',
#  'её',
#  'нажатияцифровые',
#  'входымодель',
#  'имеет',
#  'цифровых',
#  'входов',
#  'подключённых',
#  'через',
#  'две',
#  'микросхемы',
#  'содержащие',
#  'каждая',
#  'по',
#  'оптопары',
#  'возможны',
#  'два',
#  'варианта',
#  'подключения',
#  'с',
#  'плюсом',
#  'на',
#  'контакт',
#  'и',
#  'с',
#  'минусом',
#  'в',
#  'терминологии',
#  'производителя',
#  'и',
#  'аналоговые',
#  'входы',
#  'имеет',
#  'аналоговых',
#  'входа',
#  'в',
#  'реализованных',
#  'при',
#  'помощи',
#  'микросхемы',
#  'битного',
#  'аналогоцифрового',
#  'преобразователя',
#  'с',
#  'интерфейсомрасположение',
#  'на',
#  'плате',
#  'подсистемы',
#  'аналогоцифрового',
#  'преобразователя',
#  'сам',
#  'чип',
#  'распаян',
#  'на',
#  'обратной',
#  'стороне',
#  'платы',
#  'адрес',
#  'на',
#  'шине',
#  'транзисторные',
#  'выходытранзисторных',
#  'выходов',
#  'на',
#  'плате',
#  'просто',
#  'нет',
#  'их',
#  'нет',
#  'вместе',
#  'с',
#  'микросхемой',
#  'хотя',
#  'судя',
#  'по',
#  'официальной',
#  'информации',
#  'на',
#  'сайте',
#  'производителя',
#  'они',
#  'должны',
#  'бытьна',
#  'фото',
#  'отмечено',
#  'место',
#  'на',
#  'котором',
#  'должны',
#  'быть',
#  'распаяны',
#  'элементы',
#  'подсистемы',
#  'транзисторных',
#  'выходов',
#  'но',
#  'почемуто',
#  'не',
#  'распаяны',
#  'при',
#  'особом',
#  'желании',
#  'эти',
#  'элементы',
#  'можно',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основная',
#  'фишка',
#  'контроллера',
#  'модуль',
#  'установлен',
#  'на',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'вместе',
#  'с',
#  'разъёмами',
#  'для',
#  'карты',
#  'и',
#  'внешней',
#  'антенныпро',
#  'работу',
#  'этой',
#  'подсистемы',
#  'я',
#  'пока',
#  'не',
#  'могу',
#  'сказать',
#  'ничего',
#  'определённого',
#  'кроме',
#  'того',
#  'что',
#  'модуль',
#  'отзывается',
#  'на',
#  'команды',
#  'и',
#  'в',
#  'первом',
#  'приближении',
#  'ведёт',
#  'себя',
#  'нормально',
#  'и',
#  'так',
#  'как',
#  'от',
#  'него',
#  'и',
#  'ожидалось',
#  'и',
#  'скорее',
#  'всего',
#  'с',
#  'этой',
#  'подсистемой',
#  'никаких',
#  'проблем',
#  'нет',
#  'но',
#  'это',
#  'покажут',
#  'дальнейшие',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализован',
#  'по',
#  'типовой',
#  'для',
#  ...]

# %%
len(word_tokenize(t))
# Out:
# 1220

# %%
t = tokenize(t)

# %%
t
# Out:
# ['своём',
#  'блоге',
#  'рассмотрел',
#  'устройство',
#  'назначение',
#  'контроллеров',
#  'обойдены',
#  'вниманием',
#  'оказались',
#  'контроллеры',
#  'линейки',
#  'имеющие',
#  'соответствующие',
#  'модули',
#  'своём',
#  'бортукак',
#  'понимаете',
#  'наличие',
#  'модуля',
#  'является',
#  'существенным',
#  'дополнением',
#  'значительно',
#  'расширяет',
#  'возможности',
#  'контроллера',
#  'посылать',
#  'принимать',
#  'информационные',
#  'управляющие',
#  'организовать',
#  'резервный',
#  'независимый',
#  'вашей',
#  'инфраструктуры',
#  'канал',
#  'связи',
#  'т',
#  'дв',
#  'статье',
#  'рассмотрю',
#  'модель',
#  'которая',
#  'кроме',
#  'модуля',
#  'содержит',
#  'цифровые',
#  'аналоговые',
#  'входы',
#  'интерфейс',
#  'прочие',
#  'возможности',
#  'делает',
#  'контроллер',
#  'интересным',
#  'решением',
#  'создания',
#  'ваших',
#  'проектов',
#  'автоматизации',
#  'семейство',
#  'контроллеры',
#  'линейки',
#  'имеют',
#  'качестве',
#  'ядра',
#  'модуль',
#  'мб',
#  'т',
#  'д',
#  'позволяет',
#  'решать',
#  'довольно',
#  'тяжёлые',
#  'вычислительные',
#  'задачи',
#  'поддерживать',
#  'беспроводную',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрованием',
#  'данных',
#  'т',
#  'дбольшинство',
#  'моделей',
#  'контроллеров',
#  'линейки',
#  'имеют',
#  'модуль',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панели',
#  'корпуса',
#  'межблочный',
#  'интерфейс',
#  'цифровые',
#  'опторазвязанные',
#  'входы',
#  'остальные',
#  'характеристики',
#  'отличаются',
#  'составить',
#  'представление',
#  'следующей',
#  'таблицемодель',
#  'имеющаяся',
#  'моём',
#  'распоряжении',
#  'выделена',
#  'серым',
#  'фономв',
#  'моём',
#  'распоряжении',
#  'имеется',
#  'начальная',
#  'довольно',
#  'функциональная',
#  'модель',
#  'судя',
#  'вышеприведённой',
#  'таблице',
#  'взятой',
#  'официальной',
#  'документации',
#  'эта',
#  'модель',
#  'должна',
#  'иметь',
#  'транзисторных',
#  'выхода',
#  'самом',
#  'деле',
#  'отсутствуют',
#  'реальном',
#  'контроллере',
#  'это',
#  'ошибка',
#  'документации',
#  'выходы',
#  'просто',
#  'забыли',
#  'распаять',
#  'плате',
#  'сказать',
#  'трудно',
#  'судя',
#  'отсутствию',
#  'маркировки',
#  'выходов',
#  'корпусе',
#  'устройства',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллеры',
#  'линейки',
#  'содержат',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинутый',
#  'модуль',
#  'моём',
#  'случае',
#  'это',
#  'привычный',
#  'нам',
#  'штыревая',
#  'антенна',
#  'корпусе',
#  'это',
#  'антенна',
#  'модуля',
#  'компоненты',
#  'характеристикичем',
#  'порадовала',
#  'давайте',
#  'познакомимся',
#  'списком',
#  'компонентов',
#  'находящихся',
#  'борту',
#  'контроллер',
#  'модуль',
#  'внешняя',
#  'антеннаразъём',
#  'карт',
#  'цифровых',
#  'входов',
#  'светодиодов',
#  'входов',
#  'аналоговых',
#  'входа',
#  'винтерфейс',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличия',
#  'питаниянапряжение',
#  'питания',
#  'вв',
#  'целом',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничная',
#  'сбалансированная',
#  'модель',
#  'несложных',
#  'проектов',
#  'борту',
#  'присутствовали',
#  'транзисторные',
#  'выходы',
#  'заявленные',
#  'документации',
#  'всё',
#  'хорошоно',
#  'учитывая',
#  'имеет',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллера',
#  'значительно',
#  'расширить',
#  'соответствии',
#  'требованиями',
#  'вашего',
#  'проектакартину',
#  'дополняют',
#  'традиционные',
#  'отличный',
#  'дизайн',
#  'корпуса',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'светодиодные',
#  'индикаторы',
#  'таким',
#  'контроллером',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортит',
#  'внешний',
#  'вид',
#  'вашего',
#  'щитка',
#  'автоматики',
#  'разбираем',
#  'контроллересть',
#  'контроллеров',
#  'одна',
#  'неприятная',
#  'родовая',
#  'черта',
#  'практически',
#  'модели',
#  'редкими',
#  'исключениями',
#  'очень',
#  'трудно',
#  'разбираются',
#  'сказать',
#  'вообще',
#  'предназначены',
#  'разборки',
#  'процессе',
#  'вскрытия',
#  'корпуса',
#  'извлечения',
#  'контроллера',
#  'приходится',
#  'сильно',
#  'гнуть',
#  'пластмассу',
#  'рискуя',
#  'её',
#  'сломать',
#  'подвергать',
#  'механическим',
#  'нагрузкам',
#  'сами',
#  'платы',
#  'контроллерапричём',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делал',
#  'точно',
#  'знаешь',
#  'делаешь',
#  'например',
#  'время',
#  'разборки',
#  'извлечения',
#  'платы',
#  'поддона',
#  'мной',
#  'повреждена',
#  'печатная',
#  'дорожка',
#  'края',
#  'платы',
#  'выбор',
#  'велик',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмассу',
#  'корпуса',
#  'либо',
#  'риск',
#  'повредить',
#  'плату',
#  'контроллераа',
#  'существует',
#  'множество',
#  'контроллеров',
#  'которые',
#  'разбираются',
#  'легко',
#  'простов',
#  'случае',
#  'контроллеров',
#  'главными',
#  'виновниками',
#  'проблем',
#  'разборкой',
#  'сборкой',
#  'являются',
#  'боковой',
#  'разъём',
#  'расширения',
#  'слишком',
#  'мощные',
#  'фиксаторы',
#  'платы',
#  'нижней',
#  'крышке',
#  'корпуса',
#  'схемотехникавнутреннее',
#  'устройство',
#  'также',
#  'типично',
#  'контроллеров',
#  'это',
#  'всё',
#  'те',
#  'две',
#  'платы',
#  'соединённые',
#  'собой',
#  'двумя',
#  'стойками',
#  'штырьков',
#  'соединения',
#  'неразъёмные',
#  'захочется',
#  'модернизировать',
#  'значительных',
#  'усилий',
#  'хирургических',
#  'вмешательств',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзора',
#  'обзор',
#  'вынужден',
#  'упоминать',
#  'ещё',
#  'одной',
#  'родовой',
#  'проблеме',
#  'качестве',
#  'её',
#  'документации',
#  'эта',
#  'документация',
#  'просто',
#  'ужасна',
#  'одни',
#  'её',
#  'части',
#  'противоречат',
#  'другим',
#  'документация',
#  'противоречит',
#  'надписям',
#  'корпусе',
#  'контроллера',
#  'вместе',
#  'противоречат',
#  'тому',
#  'реально',
#  'железе',
#  'удивительно',
#  'само',
#  'железо',
#  'вполне',
#  'адекватное',
#  'нормально',
#  'работаетвсе',
#  'данные',
#  'компонентам',
#  'контактам',
#  'распиновкам',
#  'т',
#  'д',
#  'обзора',
#  'приходилось',
#  'проверять',
#  'перепроверять',
#  'лупой',
#  'тестером',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основании',
#  'данных',
#  'официальной',
#  'документации',
#  'категорически',
#  'рекомендуется',
#  'пользуйтесь',
#  'проверенной',
#  'информацией',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контактов',
#  'расположение',
#  'индикаторов',
#  'модификации',
#  'платы',
#  'контроллераплаты',
#  'контроллера',
#  'соединены',
#  'собой',
#  'двумя',
#  'группами',
#  'контактов',
#  'каждая',
#  'группа',
#  'содержит',
#  'контактов',
#  'сами',
#  'контакты',
#  'сделаны',
#  'неразъёмными',
#  'разобрать',
#  'контроллер',
#  'выпаивая',
#  'соединяющие',
#  'платы',
#  'перемычки',
#  'штырьки',
#  'нижняя',
#  'плата',
#  'содержит',
#  'колодки',
#  'подключения',
#  'цифровых',
#  'аналоговых',
#  'входов',
#  'питания',
#  'контроллера',
#  'также',
#  'разъём',
#  'интерфейса',
#  'плате',
#  'находятся',
#  'электронные',
#  'компоненты',
#  'соответствующих',
#  'подсистемверхняя',
#  'плата',
#  'содержит',
#  'микроконтроллер',
#  'модуль',
#  'разъёмы',
#  'подключения',
#  'карты',
#  'выносной',
#  'антенны',
#  'межблочный',
#  'интерфейс',
#  'подсистему',
#  'чипе',
#  'дисплей',
#  'управляющие',
#  'кнопки',
#  'индикаторные',
#  'светодиоды',
#  'прочие',
#  'элементыпитаниеподсистема',
#  'питания',
#  'состоит',
#  'импульсного',
#  'понижающего',
#  'регулятора',
#  'напряжения',
#  'линейного',
#  'регулятора',
#  'контроллер',
#  'рассчитан',
#  'входное',
#  'напряжение',
#  'работает',
#  'меньшего',
#  'напряжениявид',
#  'элементы',
#  'подсистемы',
#  'питания',
#  'индуктивность',
#  'диод',
#  'фильтрующие',
#  'конденсаторы',
#  'прочие',
#  'элементы',
#  'микросхема',
#  'преобразователя',
#  'спряталась',
#  'конденсатором',
#  'индуктивностью',
#  'формирующий',
#  'напряжение',
#  'находится',
#  'верхней',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъёма',
#  'данном',
#  'случае',
#  'плате',
#  'установлен',
#  'модуль',
#  'большим',
#  'пиковым',
#  'потреблением',
#  'тока',
#  'поэтому',
#  'полноценным',
#  'питанием',
#  'контакты',
#  'колодок',
#  'пренебрегатьядро',
#  'качестве',
#  'ядра',
#  'контроллер',
#  'использует',
#  'популярный',
#  'модуль',
#  'который',
#  'располагается',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'находится',
#  'линейный',
#  'регулятор',
#  'формирующий',
#  'напряжение',
#  'питаниядля',
#  'подключения',
#  'компьютеру',
#  'программирования',
#  'верхней',
#  'плате',
#  'присутствует',
#  'разъём',
#  'микросхема',
#  'преобразователя',
#  'также',
#  'прочие',
#  'элементы',
#  'кнопка',
#  'корпусе',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровые',
#  'входымодель',
#  'имеет',
#  'цифровых',
#  'входов',
#  'подключённых',
#  'две',
#  'микросхемы',
#  'содержащие',
#  'каждая',
#  'оптопары',
#  'возможны',
#  'варианта',
#  'подключения',
#  'плюсом',
#  'контакт',
#  'минусом',
#  'терминологии',
#  'производителя',
#  'аналоговые',
#  'входы',
#  'имеет',
#  'аналоговых',
#  'входа',
#  'реализованных',
#  'помощи',
#  'микросхемы',
#  'битного',
#  'аналогоцифрового',
#  'преобразователя',
#  'интерфейсомрасположение',
#  'плате',
#  'подсистемы',
#  'аналогоцифрового',
#  'преобразователя',
#  'чип',
#  'распаян',
#  'обратной',
#  'стороне',
#  'платы',
#  'адрес',
#  'шине',
#  'транзисторные',
#  'выходытранзисторных',
#  'выходов',
#  'плате',
#  'просто',
#  'вместе',
#  'микросхемой',
#  'хотя',
#  'судя',
#  'официальной',
#  'информации',
#  'сайте',
#  'производителя',
#  'должны',
#  'бытьна',
#  'фото',
#  'отмечено',
#  'место',
#  'котором',
#  'должны',
#  'распаяны',
#  'элементы',
#  'подсистемы',
#  'транзисторных',
#  'выходов',
#  'почемуто',
#  'распаяны',
#  'особом',
#  'желании',
#  'элементы',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основная',
#  'фишка',
#  'контроллера',
#  'модуль',
#  'установлен',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'вместе',
#  'разъёмами',
#  'карты',
#  'внешней',
#  'антенныпро',
#  'работу',
#  'подсистемы',
#  'пока',
#  'могу',
#  'сказать',
#  'определённого',
#  'кроме',
#  'модуль',
#  'отзывается',
#  'команды',
#  'первом',
#  'приближении',
#  'ведёт',
#  'нормально',
#  'ожидалось',
#  'скорее',
#  'подсистемой',
#  'никаких',
#  'проблем',
#  'это',
#  'покажут',
#  'дальнейшие',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализован',
#  'типовой',
#  'контроллеров',
#  'схеме',
#  'чипе',
#  'трансивера',
#  'микросхема',
#  'располагается',
#  'нижней',
#  'плате',
#  'контроллера',
#  'рядом',
#  'соответствующими',
#  'разъёмами',
#  'интерфейса',
#  'автоматическое',
#  'управление',
#  'режимами',
#  'приёмапередачи',
#  'отсутствует',
#  'микроконтроллеру',
#  'подключен',
#  'пин',
#  'дисплейв',
#  'вывода',
#  'информации',
#  'используется',
#  'дисплей',
#  'значение',
#  'факта',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найдёте',
#  'применить',
#  'ваших',
#  'проектах',
#  'адрес',
#  'дисплея',
#  'шине',
#  'кнопки',
#  'кнопки',
#  'хитрым',
#  'подключением',
#  'одному',
#  'это',
#  'подключение',
#  'позволяет',
#  'отслеживать',
#  'нажатие',
#  'кнопок',
#  'определять',
#  'сочетаниесхема',
#  'подключения',
#  'кнопок',
#  'межблочный',
#  'интерфейсконтроллеры',
#  'линейки',
#  'содержат',
#  'межблочный',
#  'интерфейс',
#  'полезное',
#  'дополнение',
#  'которое',
#  'позволяет',
#  'значительно',
#  'расширить',
#  'базовые',
#  'возможности',
#  'качестве',
#  'межблочного',
#  'интерфейса',
#  'используется',
#  'контактное',
#  'шлейфовое',
#  'соединениениже',
#  'приведена',
#  'распиновка',
#  'межблочного',
#  'разъёма',
#  'некоторые',
#  'вопросы',
#  'вызывают',
#  'пины',
#  'вопервых',
#  'назначение',
#  'соответствует',
#  'различных',
#  'серий',
#  'вовторых',
#  'согласно',
#  'официальной',
#  'документации',
#  'вообще',
#  'подключены',
#  'зная',
#  'качество',
#  'документации',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодные',
#  'индикаторысветодиодные',
#  'индикаторы',
#  'состояния',
#  'входов',
#  'шт',
#  'светодиод',
#  'наличия',
#  'напряжения',
#  'питания',
#  'фото',
#  'видно',
#  'светодиода',
#  'цифровых',
#  'выходов',
#  'распаяны',
#  'распиновкараспиновка',
#  'контроллера',
#  'желтым',
#  'цветом',
#  'помечены',
#  'контакты',
#  'выведенные',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'осталось',
#  'незадействованными',
#  'будут',
#  'использоваться',
#  'старших',
#  'моделях',
#  'серии',
#  'большим',
#  'количеством',
#  'подключённых',
#  'компонентов',
#  'заключениев',
#  'качестве',
#  'заключения',
#  'сказать',
#  'это',
#  'довольно',
#  'интересная',
#  'модель',
#  'микроконтроллере',
#  'наличие',
#  'модуля',
#  'значительно',
#  'расширяет',
#  'её',
#  'возможности',
#  'создания',
#  'проектов',
#  'стоит',
#  'также',
#  'отметить',
#  'модель',
#  'имеет',
#  'разъём',
#  'подключения',
#  'дополнительных',
#  'блоков',
#  'позволяет',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решений',
#  'её',
#  'основе']

# %%
len(t)
# Out:
# 887

# %%
# !pip install pymorphy2
# Out:
# Collecting pymorphy2
#   Downloading pymorphy2-0.9.1-py3-none-any.whl (55 kB)
# Collecting docopt>=0.6
#   Downloading docopt-0.6.2.tar.gz (25 kB)
# Collecting pymorphy2-dicts-ru<3.0,>=2.4
#   Downloading pymorphy2_dicts_ru-2.4.417127.4579844-py2.py3-none-any.whl (8.2 MB)
# Collecting dawg-python>=0.7.1
#   Downloading DAWG_Python-0.7.2-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: docopt
#   Building wheel for docopt (setup.py): started
#   Building wheel for docopt (setup.py): finished with status 'done'
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13705 sha256=b22b2d4a821924db45bb037831cc7ee7db0765d9cf8c683f2a40dc511db025f1
#   Stored in directory: c:\users\моибд\appdata\local\pip\cache\wheels\56\ea\58\ead137b087d9e326852a851351d1debf4ada529b6ac0ec4e8c
# Successfully built docopt
# Installing collected packages: pymorphy2-dicts-ru, docopt, dawg-python, pymorphy2
# Successfully installed dawg-python-0.7.2 docopt-0.6.2 pymorphy2-0.9.1 pymorphy2-dicts-ru-2.4.417127.4579844

# %% [markdown]
# 5. Стемминг

# %%
from nltk.stem import PorterStemmer

# %%
ps = PorterStemmer()
def stemming(text):
    tokenized_text = [ps.stem(word) for word in text]
    return tokenized_text

# %%
t1 = stemming(t)

# %%
t1
# Out:
# ['своём',
#  'блоге',
#  'рассмотрел',
#  'устройство',
#  'назначение',
#  'контроллеров',
#  'обойдены',
#  'вниманием',
#  'оказались',
#  'контроллеры',
#  'линейки',
#  'имеющие',
#  'соответствующие',
#  'модули',
#  'своём',
#  'бортукак',
#  'понимаете',
#  'наличие',
#  'модуля',
#  'является',
#  'существенным',
#  'дополнением',
#  'значительно',
#  'расширяет',
#  'возможности',
#  'контроллера',
#  'посылать',
#  'принимать',
#  'информационные',
#  'управляющие',
#  'организовать',
#  'резервный',
#  'независимый',
#  'вашей',
#  'инфраструктуры',
#  'канал',
#  'связи',
#  'т',
#  'дв',
#  'статье',
#  'рассмотрю',
#  'модель',
#  'которая',
#  'кроме',
#  'модуля',
#  'содержит',
#  'цифровые',
#  'аналоговые',
#  'входы',
#  'интерфейс',
#  'прочие',
#  'возможности',
#  'делает',
#  'контроллер',
#  'интересным',
#  'решением',
#  'создания',
#  'ваших',
#  'проектов',
#  'автоматизации',
#  'семейство',
#  'контроллеры',
#  'линейки',
#  'имеют',
#  'качестве',
#  'ядра',
#  'модуль',
#  'мб',
#  'т',
#  'д',
#  'позволяет',
#  'решать',
#  'довольно',
#  'тяжёлые',
#  'вычислительные',
#  'задачи',
#  'поддерживать',
#  'беспроводную',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрованием',
#  'данных',
#  'т',
#  'дбольшинство',
#  'моделей',
#  'контроллеров',
#  'линейки',
#  'имеют',
#  'модуль',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панели',
#  'корпуса',
#  'межблочный',
#  'интерфейс',
#  'цифровые',
#  'опторазвязанные',
#  'входы',
#  'остальные',
#  'характеристики',
#  'отличаются',
#  'составить',
#  'представление',
#  'следующей',
#  'таблицемодель',
#  'имеющаяся',
#  'моём',
#  'распоряжении',
#  'выделена',
#  'серым',
#  'фономв',
#  'моём',
#  'распоряжении',
#  'имеется',
#  'начальная',
#  'довольно',
#  'функциональная',
#  'модель',
#  'судя',
#  'вышеприведённой',
#  'таблице',
#  'взятой',
#  'официальной',
#  'документации',
#  'эта',
#  'модель',
#  'должна',
#  'иметь',
#  'транзисторных',
#  'выхода',
#  'самом',
#  'деле',
#  'отсутствуют',
#  'реальном',
#  'контроллере',
#  'это',
#  'ошибка',
#  'документации',
#  'выходы',
#  'просто',
#  'забыли',
#  'распаять',
#  'плате',
#  'сказать',
#  'трудно',
#  'судя',
#  'отсутствию',
#  'маркировки',
#  'выходов',
#  'корпусе',
#  'устройства',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллеры',
#  'линейки',
#  'содержат',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинутый',
#  'модуль',
#  'моём',
#  'случае',
#  'это',
#  'привычный',
#  'нам',
#  'штыревая',
#  'антенна',
#  'корпусе',
#  'это',
#  'антенна',
#  'модуля',
#  'компоненты',
#  'характеристикичем',
#  'порадовала',
#  'давайте',
#  'познакомимся',
#  'списком',
#  'компонентов',
#  'находящихся',
#  'борту',
#  'контроллер',
#  'модуль',
#  'внешняя',
#  'антеннаразъём',
#  'карт',
#  'цифровых',
#  'входов',
#  'светодиодов',
#  'входов',
#  'аналоговых',
#  'входа',
#  'винтерфейс',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличия',
#  'питаниянапряжение',
#  'питания',
#  'вв',
#  'целом',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничная',
#  'сбалансированная',
#  'модель',
#  'несложных',
#  'проектов',
#  'борту',
#  'присутствовали',
#  'транзисторные',
#  'выходы',
#  'заявленные',
#  'документации',
#  'всё',
#  'хорошоно',
#  'учитывая',
#  'имеет',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллера',
#  'значительно',
#  'расширить',
#  'соответствии',
#  'требованиями',
#  'вашего',
#  'проектакартину',
#  'дополняют',
#  'традиционные',
#  'отличный',
#  'дизайн',
#  'корпуса',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'светодиодные',
#  'индикаторы',
#  'таким',
#  'контроллером',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортит',
#  'внешний',
#  'вид',
#  'вашего',
#  'щитка',
#  'автоматики',
#  'разбираем',
#  'контроллересть',
#  'контроллеров',
#  'одна',
#  'неприятная',
#  'родовая',
#  'черта',
#  'практически',
#  'модели',
#  'редкими',
#  'исключениями',
#  'очень',
#  'трудно',
#  'разбираются',
#  'сказать',
#  'вообще',
#  'предназначены',
#  'разборки',
#  'процессе',
#  'вскрытия',
#  'корпуса',
#  'извлечения',
#  'контроллера',
#  'приходится',
#  'сильно',
#  'гнуть',
#  'пластмассу',
#  'рискуя',
#  'её',
#  'сломать',
#  'подвергать',
#  'механическим',
#  'нагрузкам',
#  'сами',
#  'платы',
#  'контроллерапричём',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делал',
#  'точно',
#  'знаешь',
#  'делаешь',
#  'например',
#  'время',
#  'разборки',
#  'извлечения',
#  'платы',
#  'поддона',
#  'мной',
#  'повреждена',
#  'печатная',
#  'дорожка',
#  'края',
#  'платы',
#  'выбор',
#  'велик',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмассу',
#  'корпуса',
#  'либо',
#  'риск',
#  'повредить',
#  'плату',
#  'контроллераа',
#  'существует',
#  'множество',
#  'контроллеров',
#  'которые',
#  'разбираются',
#  'легко',
#  'простов',
#  'случае',
#  'контроллеров',
#  'главными',
#  'виновниками',
#  'проблем',
#  'разборкой',
#  'сборкой',
#  'являются',
#  'боковой',
#  'разъём',
#  'расширения',
#  'слишком',
#  'мощные',
#  'фиксаторы',
#  'платы',
#  'нижней',
#  'крышке',
#  'корпуса',
#  'схемотехникавнутреннее',
#  'устройство',
#  'также',
#  'типично',
#  'контроллеров',
#  'это',
#  'всё',
#  'те',
#  'две',
#  'платы',
#  'соединённые',
#  'собой',
#  'двумя',
#  'стойками',
#  'штырьков',
#  'соединения',
#  'неразъёмные',
#  'захочется',
#  'модернизировать',
#  'значительных',
#  'усилий',
#  'хирургических',
#  'вмешательств',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзора',
#  'обзор',
#  'вынужден',
#  'упоминать',
#  'ещё',
#  'одной',
#  'родовой',
#  'проблеме',
#  'качестве',
#  'её',
#  'документации',
#  'эта',
#  'документация',
#  'просто',
#  'ужасна',
#  'одни',
#  'её',
#  'части',
#  'противоречат',
#  'другим',
#  'документация',
#  'противоречит',
#  'надписям',
#  'корпусе',
#  'контроллера',
#  'вместе',
#  'противоречат',
#  'тому',
#  'реально',
#  'железе',
#  'удивительно',
#  'само',
#  'железо',
#  'вполне',
#  'адекватное',
#  'нормально',
#  'работаетвсе',
#  'данные',
#  'компонентам',
#  'контактам',
#  'распиновкам',
#  'т',
#  'д',
#  'обзора',
#  'приходилось',
#  'проверять',
#  'перепроверять',
#  'лупой',
#  'тестером',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основании',
#  'данных',
#  'официальной',
#  'документации',
#  'категорически',
#  'рекомендуется',
#  'пользуйтесь',
#  'проверенной',
#  'информацией',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контактов',
#  'расположение',
#  'индикаторов',
#  'модификации',
#  'платы',
#  'контроллераплаты',
#  'контроллера',
#  'соединены',
#  'собой',
#  'двумя',
#  'группами',
#  'контактов',
#  'каждая',
#  'группа',
#  'содержит',
#  'контактов',
#  'сами',
#  'контакты',
#  'сделаны',
#  'неразъёмными',
#  'разобрать',
#  'контроллер',
#  'выпаивая',
#  'соединяющие',
#  'платы',
#  'перемычки',
#  'штырьки',
#  'нижняя',
#  'плата',
#  'содержит',
#  'колодки',
#  'подключения',
#  'цифровых',
#  'аналоговых',
#  'входов',
#  'питания',
#  'контроллера',
#  'также',
#  'разъём',
#  'интерфейса',
#  'плате',
#  'находятся',
#  'электронные',
#  'компоненты',
#  'соответствующих',
#  'подсистемверхняя',
#  'плата',
#  'содержит',
#  'микроконтроллер',
#  'модуль',
#  'разъёмы',
#  'подключения',
#  'карты',
#  'выносной',
#  'антенны',
#  'межблочный',
#  'интерфейс',
#  'подсистему',
#  'чипе',
#  'дисплей',
#  'управляющие',
#  'кнопки',
#  'индикаторные',
#  'светодиоды',
#  'прочие',
#  'элементыпитаниеподсистема',
#  'питания',
#  'состоит',
#  'импульсного',
#  'понижающего',
#  'регулятора',
#  'напряжения',
#  'линейного',
#  'регулятора',
#  'контроллер',
#  'рассчитан',
#  'входное',
#  'напряжение',
#  'работает',
#  'меньшего',
#  'напряжениявид',
#  'элементы',
#  'подсистемы',
#  'питания',
#  'индуктивность',
#  'диод',
#  'фильтрующие',
#  'конденсаторы',
#  'прочие',
#  'элементы',
#  'микросхема',
#  'преобразователя',
#  'спряталась',
#  'конденсатором',
#  'индуктивностью',
#  'формирующий',
#  'напряжение',
#  'находится',
#  'верхней',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъёма',
#  'данном',
#  'случае',
#  'плате',
#  'установлен',
#  'модуль',
#  'большим',
#  'пиковым',
#  'потреблением',
#  'тока',
#  'поэтому',
#  'полноценным',
#  'питанием',
#  'контакты',
#  'колодок',
#  'пренебрегатьядро',
#  'качестве',
#  'ядра',
#  'контроллер',
#  'использует',
#  'популярный',
#  'модуль',
#  'который',
#  'располагается',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'находится',
#  'линейный',
#  'регулятор',
#  'формирующий',
#  'напряжение',
#  'питаниядля',
#  'подключения',
#  'компьютеру',
#  'программирования',
#  'верхней',
#  'плате',
#  'присутствует',
#  'разъём',
#  'микросхема',
#  'преобразователя',
#  'также',
#  'прочие',
#  'элементы',
#  'кнопка',
#  'корпусе',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровые',
#  'входымодель',
#  'имеет',
#  'цифровых',
#  'входов',
#  'подключённых',
#  'две',
#  'микросхемы',
#  'содержащие',
#  'каждая',
#  'оптопары',
#  'возможны',
#  'варианта',
#  'подключения',
#  'плюсом',
#  'контакт',
#  'минусом',
#  'терминологии',
#  'производителя',
#  'аналоговые',
#  'входы',
#  'имеет',
#  'аналоговых',
#  'входа',
#  'реализованных',
#  'помощи',
#  'микросхемы',
#  'битного',
#  'аналогоцифрового',
#  'преобразователя',
#  'интерфейсомрасположение',
#  'плате',
#  'подсистемы',
#  'аналогоцифрового',
#  'преобразователя',
#  'чип',
#  'распаян',
#  'обратной',
#  'стороне',
#  'платы',
#  'адрес',
#  'шине',
#  'транзисторные',
#  'выходытранзисторных',
#  'выходов',
#  'плате',
#  'просто',
#  'вместе',
#  'микросхемой',
#  'хотя',
#  'судя',
#  'официальной',
#  'информации',
#  'сайте',
#  'производителя',
#  'должны',
#  'бытьна',
#  'фото',
#  'отмечено',
#  'место',
#  'котором',
#  'должны',
#  'распаяны',
#  'элементы',
#  'подсистемы',
#  'транзисторных',
#  'выходов',
#  'почемуто',
#  'распаяны',
#  'особом',
#  'желании',
#  'элементы',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основная',
#  'фишка',
#  'контроллера',
#  'модуль',
#  'установлен',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'вместе',
#  'разъёмами',
#  'карты',
#  'внешней',
#  'антенныпро',
#  'работу',
#  'подсистемы',
#  'пока',
#  'могу',
#  'сказать',
#  'определённого',
#  'кроме',
#  'модуль',
#  'отзывается',
#  'команды',
#  'первом',
#  'приближении',
#  'ведёт',
#  'нормально',
#  'ожидалось',
#  'скорее',
#  'подсистемой',
#  'никаких',
#  'проблем',
#  'это',
#  'покажут',
#  'дальнейшие',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализован',
#  'типовой',
#  'контроллеров',
#  'схеме',
#  'чипе',
#  'трансивера',
#  'микросхема',
#  'располагается',
#  'нижней',
#  'плате',
#  'контроллера',
#  'рядом',
#  'соответствующими',
#  'разъёмами',
#  'интерфейса',
#  'автоматическое',
#  'управление',
#  'режимами',
#  'приёмапередачи',
#  'отсутствует',
#  'микроконтроллеру',
#  'подключен',
#  'пин',
#  'дисплейв',
#  'вывода',
#  'информации',
#  'используется',
#  'дисплей',
#  'значение',
#  'факта',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найдёте',
#  'применить',
#  'ваших',
#  'проектах',
#  'адрес',
#  'дисплея',
#  'шине',
#  'кнопки',
#  'кнопки',
#  'хитрым',
#  'подключением',
#  'одному',
#  'это',
#  'подключение',
#  'позволяет',
#  'отслеживать',
#  'нажатие',
#  'кнопок',
#  'определять',
#  'сочетаниесхема',
#  'подключения',
#  'кнопок',
#  'межблочный',
#  'интерфейсконтроллеры',
#  'линейки',
#  'содержат',
#  'межблочный',
#  'интерфейс',
#  'полезное',
#  'дополнение',
#  'которое',
#  'позволяет',
#  'значительно',
#  'расширить',
#  'базовые',
#  'возможности',
#  'качестве',
#  'межблочного',
#  'интерфейса',
#  'используется',
#  'контактное',
#  'шлейфовое',
#  'соединениениже',
#  'приведена',
#  'распиновка',
#  'межблочного',
#  'разъёма',
#  'некоторые',
#  'вопросы',
#  'вызывают',
#  'пины',
#  'вопервых',
#  'назначение',
#  'соответствует',
#  'различных',
#  'серий',
#  'вовторых',
#  'согласно',
#  'официальной',
#  'документации',
#  'вообще',
#  'подключены',
#  'зная',
#  'качество',
#  'документации',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодные',
#  'индикаторысветодиодные',
#  'индикаторы',
#  'состояния',
#  'входов',
#  'шт',
#  'светодиод',
#  'наличия',
#  'напряжения',
#  'питания',
#  'фото',
#  'видно',
#  'светодиода',
#  'цифровых',
#  'выходов',
#  'распаяны',
#  'распиновкараспиновка',
#  'контроллера',
#  'желтым',
#  'цветом',
#  'помечены',
#  'контакты',
#  'выведенные',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'осталось',
#  'незадействованными',
#  'будут',
#  'использоваться',
#  'старших',
#  'моделях',
#  'серии',
#  'большим',
#  'количеством',
#  'подключённых',
#  'компонентов',
#  'заключениев',
#  'качестве',
#  'заключения',
#  'сказать',
#  'это',
#  'довольно',
#  'интересная',
#  'модель',
#  'микроконтроллере',
#  'наличие',
#  'модуля',
#  'значительно',
#  'расширяет',
#  'её',
#  'возможности',
#  'создания',
#  'проектов',
#  'стоит',
#  'также',
#  'отметить',
#  'модель',
#  'имеет',
#  'разъём',
#  'подключения',
#  'дополнительных',
#  'блоков',
#  'позволяет',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решений',
#  'её',
#  'основе']

# %%
len(t1)
# Out:
# 887

# %%
from nltk.stem import LancasterStemmer
lancaster = LancasterStemmer()
def stemming2(text):
    tokenized_text = [lancaster.stem(word) for word in text]
    return tokenized_text

# %%
t3 = stemming2(t)

# %%
t3
# Out:
# ['своём',
#  'блоге',
#  'рассмотрел',
#  'устройство',
#  'назначение',
#  'контроллеров',
#  'обойдены',
#  'вниманием',
#  'оказались',
#  'контроллеры',
#  'линейки',
#  'имеющие',
#  'соответствующие',
#  'модули',
#  'своём',
#  'бортукак',
#  'понимаете',
#  'наличие',
#  'модуля',
#  'является',
#  'существенным',
#  'дополнением',
#  'значительно',
#  'расширяет',
#  'возможности',
#  'контроллера',
#  'посылать',
#  'принимать',
#  'информационные',
#  'управляющие',
#  'организовать',
#  'резервный',
#  'независимый',
#  'вашей',
#  'инфраструктуры',
#  'канал',
#  'связи',
#  'т',
#  'дв',
#  'статье',
#  'рассмотрю',
#  'модель',
#  'которая',
#  'кроме',
#  'модуля',
#  'содержит',
#  'цифровые',
#  'аналоговые',
#  'входы',
#  'интерфейс',
#  'прочие',
#  'возможности',
#  'делает',
#  'контроллер',
#  'интересным',
#  'решением',
#  'создания',
#  'ваших',
#  'проектов',
#  'автоматизации',
#  'семейство',
#  'контроллеры',
#  'линейки',
#  'имеют',
#  'качестве',
#  'ядра',
#  'модуль',
#  'мб',
#  'т',
#  'д',
#  'позволяет',
#  'решать',
#  'довольно',
#  'тяжёлые',
#  'вычислительные',
#  'задачи',
#  'поддерживать',
#  'беспроводную',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрованием',
#  'данных',
#  'т',
#  'дбольшинство',
#  'моделей',
#  'контроллеров',
#  'линейки',
#  'имеют',
#  'модуль',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панели',
#  'корпуса',
#  'межблочный',
#  'интерфейс',
#  'цифровые',
#  'опторазвязанные',
#  'входы',
#  'остальные',
#  'характеристики',
#  'отличаются',
#  'составить',
#  'представление',
#  'следующей',
#  'таблицемодель',
#  'имеющаяся',
#  'моём',
#  'распоряжении',
#  'выделена',
#  'серым',
#  'фономв',
#  'моём',
#  'распоряжении',
#  'имеется',
#  'начальная',
#  'довольно',
#  'функциональная',
#  'модель',
#  'судя',
#  'вышеприведённой',
#  'таблице',
#  'взятой',
#  'официальной',
#  'документации',
#  'эта',
#  'модель',
#  'должна',
#  'иметь',
#  'транзисторных',
#  'выхода',
#  'самом',
#  'деле',
#  'отсутствуют',
#  'реальном',
#  'контроллере',
#  'это',
#  'ошибка',
#  'документации',
#  'выходы',
#  'просто',
#  'забыли',
#  'распаять',
#  'плате',
#  'сказать',
#  'трудно',
#  'судя',
#  'отсутствию',
#  'маркировки',
#  'выходов',
#  'корпусе',
#  'устройства',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллеры',
#  'линейки',
#  'содержат',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинутый',
#  'модуль',
#  'моём',
#  'случае',
#  'это',
#  'привычный',
#  'нам',
#  'штыревая',
#  'антенна',
#  'корпусе',
#  'это',
#  'антенна',
#  'модуля',
#  'компоненты',
#  'характеристикичем',
#  'порадовала',
#  'давайте',
#  'познакомимся',
#  'списком',
#  'компонентов',
#  'находящихся',
#  'борту',
#  'контроллер',
#  'модуль',
#  'внешняя',
#  'антеннаразъём',
#  'карт',
#  'цифровых',
#  'входов',
#  'светодиодов',
#  'входов',
#  'аналоговых',
#  'входа',
#  'винтерфейс',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличия',
#  'питаниянапряжение',
#  'питания',
#  'вв',
#  'целом',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничная',
#  'сбалансированная',
#  'модель',
#  'несложных',
#  'проектов',
#  'борту',
#  'присутствовали',
#  'транзисторные',
#  'выходы',
#  'заявленные',
#  'документации',
#  'всё',
#  'хорошоно',
#  'учитывая',
#  'имеет',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллера',
#  'значительно',
#  'расширить',
#  'соответствии',
#  'требованиями',
#  'вашего',
#  'проектакартину',
#  'дополняют',
#  'традиционные',
#  'отличный',
#  'дизайн',
#  'корпуса',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'светодиодные',
#  'индикаторы',
#  'таким',
#  'контроллером',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортит',
#  'внешний',
#  'вид',
#  'вашего',
#  'щитка',
#  'автоматики',
#  'разбираем',
#  'контроллересть',
#  'контроллеров',
#  'одна',
#  'неприятная',
#  'родовая',
#  'черта',
#  'практически',
#  'модели',
#  'редкими',
#  'исключениями',
#  'очень',
#  'трудно',
#  'разбираются',
#  'сказать',
#  'вообще',
#  'предназначены',
#  'разборки',
#  'процессе',
#  'вскрытия',
#  'корпуса',
#  'извлечения',
#  'контроллера',
#  'приходится',
#  'сильно',
#  'гнуть',
#  'пластмассу',
#  'рискуя',
#  'её',
#  'сломать',
#  'подвергать',
#  'механическим',
#  'нагрузкам',
#  'сами',
#  'платы',
#  'контроллерапричём',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делал',
#  'точно',
#  'знаешь',
#  'делаешь',
#  'например',
#  'время',
#  'разборки',
#  'извлечения',
#  'платы',
#  'поддона',
#  'мной',
#  'повреждена',
#  'печатная',
#  'дорожка',
#  'края',
#  'платы',
#  'выбор',
#  'велик',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмассу',
#  'корпуса',
#  'либо',
#  'риск',
#  'повредить',
#  'плату',
#  'контроллераа',
#  'существует',
#  'множество',
#  'контроллеров',
#  'которые',
#  'разбираются',
#  'легко',
#  'простов',
#  'случае',
#  'контроллеров',
#  'главными',
#  'виновниками',
#  'проблем',
#  'разборкой',
#  'сборкой',
#  'являются',
#  'боковой',
#  'разъём',
#  'расширения',
#  'слишком',
#  'мощные',
#  'фиксаторы',
#  'платы',
#  'нижней',
#  'крышке',
#  'корпуса',
#  'схемотехникавнутреннее',
#  'устройство',
#  'также',
#  'типично',
#  'контроллеров',
#  'это',
#  'всё',
#  'те',
#  'две',
#  'платы',
#  'соединённые',
#  'собой',
#  'двумя',
#  'стойками',
#  'штырьков',
#  'соединения',
#  'неразъёмные',
#  'захочется',
#  'модернизировать',
#  'значительных',
#  'усилий',
#  'хирургических',
#  'вмешательств',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзора',
#  'обзор',
#  'вынужден',
#  'упоминать',
#  'ещё',
#  'одной',
#  'родовой',
#  'проблеме',
#  'качестве',
#  'её',
#  'документации',
#  'эта',
#  'документация',
#  'просто',
#  'ужасна',
#  'одни',
#  'её',
#  'части',
#  'противоречат',
#  'другим',
#  'документация',
#  'противоречит',
#  'надписям',
#  'корпусе',
#  'контроллера',
#  'вместе',
#  'противоречат',
#  'тому',
#  'реально',
#  'железе',
#  'удивительно',
#  'само',
#  'железо',
#  'вполне',
#  'адекватное',
#  'нормально',
#  'работаетвсе',
#  'данные',
#  'компонентам',
#  'контактам',
#  'распиновкам',
#  'т',
#  'д',
#  'обзора',
#  'приходилось',
#  'проверять',
#  'перепроверять',
#  'лупой',
#  'тестером',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основании',
#  'данных',
#  'официальной',
#  'документации',
#  'категорически',
#  'рекомендуется',
#  'пользуйтесь',
#  'проверенной',
#  'информацией',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контактов',
#  'расположение',
#  'индикаторов',
#  'модификации',
#  'платы',
#  'контроллераплаты',
#  'контроллера',
#  'соединены',
#  'собой',
#  'двумя',
#  'группами',
#  'контактов',
#  'каждая',
#  'группа',
#  'содержит',
#  'контактов',
#  'сами',
#  'контакты',
#  'сделаны',
#  'неразъёмными',
#  'разобрать',
#  'контроллер',
#  'выпаивая',
#  'соединяющие',
#  'платы',
#  'перемычки',
#  'штырьки',
#  'нижняя',
#  'плата',
#  'содержит',
#  'колодки',
#  'подключения',
#  'цифровых',
#  'аналоговых',
#  'входов',
#  'питания',
#  'контроллера',
#  'также',
#  'разъём',
#  'интерфейса',
#  'плате',
#  'находятся',
#  'электронные',
#  'компоненты',
#  'соответствующих',
#  'подсистемверхняя',
#  'плата',
#  'содержит',
#  'микроконтроллер',
#  'модуль',
#  'разъёмы',
#  'подключения',
#  'карты',
#  'выносной',
#  'антенны',
#  'межблочный',
#  'интерфейс',
#  'подсистему',
#  'чипе',
#  'дисплей',
#  'управляющие',
#  'кнопки',
#  'индикаторные',
#  'светодиоды',
#  'прочие',
#  'элементыпитаниеподсистема',
#  'питания',
#  'состоит',
#  'импульсного',
#  'понижающего',
#  'регулятора',
#  'напряжения',
#  'линейного',
#  'регулятора',
#  'контроллер',
#  'рассчитан',
#  'входное',
#  'напряжение',
#  'работает',
#  'меньшего',
#  'напряжениявид',
#  'элементы',
#  'подсистемы',
#  'питания',
#  'индуктивность',
#  'диод',
#  'фильтрующие',
#  'конденсаторы',
#  'прочие',
#  'элементы',
#  'микросхема',
#  'преобразователя',
#  'спряталась',
#  'конденсатором',
#  'индуктивностью',
#  'формирующий',
#  'напряжение',
#  'находится',
#  'верхней',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъёма',
#  'данном',
#  'случае',
#  'плате',
#  'установлен',
#  'модуль',
#  'большим',
#  'пиковым',
#  'потреблением',
#  'тока',
#  'поэтому',
#  'полноценным',
#  'питанием',
#  'контакты',
#  'колодок',
#  'пренебрегатьядро',
#  'качестве',
#  'ядра',
#  'контроллер',
#  'использует',
#  'популярный',
#  'модуль',
#  'который',
#  'располагается',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'находится',
#  'линейный',
#  'регулятор',
#  'формирующий',
#  'напряжение',
#  'питаниядля',
#  'подключения',
#  'компьютеру',
#  'программирования',
#  'верхней',
#  'плате',
#  'присутствует',
#  'разъём',
#  'микросхема',
#  'преобразователя',
#  'также',
#  'прочие',
#  'элементы',
#  'кнопка',
#  'корпусе',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровые',
#  'входымодель',
#  'имеет',
#  'цифровых',
#  'входов',
#  'подключённых',
#  'две',
#  'микросхемы',
#  'содержащие',
#  'каждая',
#  'оптопары',
#  'возможны',
#  'варианта',
#  'подключения',
#  'плюсом',
#  'контакт',
#  'минусом',
#  'терминологии',
#  'производителя',
#  'аналоговые',
#  'входы',
#  'имеет',
#  'аналоговых',
#  'входа',
#  'реализованных',
#  'помощи',
#  'микросхемы',
#  'битного',
#  'аналогоцифрового',
#  'преобразователя',
#  'интерфейсомрасположение',
#  'плате',
#  'подсистемы',
#  'аналогоцифрового',
#  'преобразователя',
#  'чип',
#  'распаян',
#  'обратной',
#  'стороне',
#  'платы',
#  'адрес',
#  'шине',
#  'транзисторные',
#  'выходытранзисторных',
#  'выходов',
#  'плате',
#  'просто',
#  'вместе',
#  'микросхемой',
#  'хотя',
#  'судя',
#  'официальной',
#  'информации',
#  'сайте',
#  'производителя',
#  'должны',
#  'бытьна',
#  'фото',
#  'отмечено',
#  'место',
#  'котором',
#  'должны',
#  'распаяны',
#  'элементы',
#  'подсистемы',
#  'транзисторных',
#  'выходов',
#  'почемуто',
#  'распаяны',
#  'особом',
#  'желании',
#  'элементы',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основная',
#  'фишка',
#  'контроллера',
#  'модуль',
#  'установлен',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'вместе',
#  'разъёмами',
#  'карты',
#  'внешней',
#  'антенныпро',
#  'работу',
#  'подсистемы',
#  'пока',
#  'могу',
#  'сказать',
#  'определённого',
#  'кроме',
#  'модуль',
#  'отзывается',
#  'команды',
#  'первом',
#  'приближении',
#  'ведёт',
#  'нормально',
#  'ожидалось',
#  'скорее',
#  'подсистемой',
#  'никаких',
#  'проблем',
#  'это',
#  'покажут',
#  'дальнейшие',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализован',
#  'типовой',
#  'контроллеров',
#  'схеме',
#  'чипе',
#  'трансивера',
#  'микросхема',
#  'располагается',
#  'нижней',
#  'плате',
#  'контроллера',
#  'рядом',
#  'соответствующими',
#  'разъёмами',
#  'интерфейса',
#  'автоматическое',
#  'управление',
#  'режимами',
#  'приёмапередачи',
#  'отсутствует',
#  'микроконтроллеру',
#  'подключен',
#  'пин',
#  'дисплейв',
#  'вывода',
#  'информации',
#  'используется',
#  'дисплей',
#  'значение',
#  'факта',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найдёте',
#  'применить',
#  'ваших',
#  'проектах',
#  'адрес',
#  'дисплея',
#  'шине',
#  'кнопки',
#  'кнопки',
#  'хитрым',
#  'подключением',
#  'одному',
#  'это',
#  'подключение',
#  'позволяет',
#  'отслеживать',
#  'нажатие',
#  'кнопок',
#  'определять',
#  'сочетаниесхема',
#  'подключения',
#  'кнопок',
#  'межблочный',
#  'интерфейсконтроллеры',
#  'линейки',
#  'содержат',
#  'межблочный',
#  'интерфейс',
#  'полезное',
#  'дополнение',
#  'которое',
#  'позволяет',
#  'значительно',
#  'расширить',
#  'базовые',
#  'возможности',
#  'качестве',
#  'межблочного',
#  'интерфейса',
#  'используется',
#  'контактное',
#  'шлейфовое',
#  'соединениениже',
#  'приведена',
#  'распиновка',
#  'межблочного',
#  'разъёма',
#  'некоторые',
#  'вопросы',
#  'вызывают',
#  'пины',
#  'вопервых',
#  'назначение',
#  'соответствует',
#  'различных',
#  'серий',
#  'вовторых',
#  'согласно',
#  'официальной',
#  'документации',
#  'вообще',
#  'подключены',
#  'зная',
#  'качество',
#  'документации',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодные',
#  'индикаторысветодиодные',
#  'индикаторы',
#  'состояния',
#  'входов',
#  'шт',
#  'светодиод',
#  'наличия',
#  'напряжения',
#  'питания',
#  'фото',
#  'видно',
#  'светодиода',
#  'цифровых',
#  'выходов',
#  'распаяны',
#  'распиновкараспиновка',
#  'контроллера',
#  'желтым',
#  'цветом',
#  'помечены',
#  'контакты',
#  'выведенные',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'осталось',
#  'незадействованными',
#  'будут',
#  'использоваться',
#  'старших',
#  'моделях',
#  'серии',
#  'большим',
#  'количеством',
#  'подключённых',
#  'компонентов',
#  'заключениев',
#  'качестве',
#  'заключения',
#  'сказать',
#  'это',
#  'довольно',
#  'интересная',
#  'модель',
#  'микроконтроллере',
#  'наличие',
#  'модуля',
#  'значительно',
#  'расширяет',
#  'её',
#  'возможности',
#  'создания',
#  'проектов',
#  'стоит',
#  'также',
#  'отметить',
#  'модель',
#  'имеет',
#  'разъём',
#  'подключения',
#  'дополнительных',
#  'блоков',
#  'позволяет',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решений',
#  'её',
#  'основе']

# %%
from nltk.stem import SnowballStemmer
snowball = SnowballStemmer("russian")
def stemming3(text):
    tokenized_text = [snowball.stem(word) for word in text]
    return tokenized_text

# %%
t4 = stemming3(t)

# %%
t4
# Out:
# ['сво',
#  'блог',
#  'рассмотрел',
#  'устройств',
#  'назначен',
#  'контроллер',
#  'обойд',
#  'вниман',
#  'оказа',
#  'контроллер',
#  'линейк',
#  'имеющ',
#  'соответств',
#  'модул',
#  'сво',
#  'бортукак',
#  'понима',
#  'налич',
#  'модул',
#  'явля',
#  'существен',
#  'дополнен',
#  'значительн',
#  'расширя',
#  'возможн',
#  'контроллер',
#  'посыла',
#  'принима',
#  'информацион',
#  'управля',
#  'организова',
#  'резервн',
#  'независим',
#  'ваш',
#  'инфраструктур',
#  'кана',
#  'связ',
#  'т',
#  'дв',
#  'стат',
#  'рассмотр',
#  'модел',
#  'котор',
#  'кром',
#  'модул',
#  'содерж',
#  'цифров',
#  'аналогов',
#  'вход',
#  'интерфейс',
#  'проч',
#  'возможн',
#  'дела',
#  'контроллер',
#  'интересн',
#  'решен',
#  'создан',
#  'ваш',
#  'проект',
#  'автоматизац',
#  'семейств',
#  'контроллер',
#  'линейк',
#  'имеют',
#  'качеств',
#  'ядр',
#  'модул',
#  'мб',
#  'т',
#  'д',
#  'позволя',
#  'реша',
#  'довольн',
#  'тяжел',
#  'вычислительн',
#  'задач',
#  'поддержива',
#  'беспроводн',
#  'связ',
#  'полноцен',
#  'вебинтерфейс',
#  'работа',
#  'шифрован',
#  'дан',
#  'т',
#  'дбольшинств',
#  'модел',
#  'контроллер',
#  'линейк',
#  'имеют',
#  'модул',
#  'диспл',
#  'кнопк',
#  'управлен',
#  'передн',
#  'панел',
#  'корпус',
#  'межблочн',
#  'интерфейс',
#  'цифров',
#  'опторазвяза',
#  'вход',
#  'остальн',
#  'характеристик',
#  'отлича',
#  'состав',
#  'представлен',
#  'след',
#  'таблицемодел',
#  'имеющ',
#  'мо',
#  'распоряжен',
#  'выдел',
#  'сер',
#  'фономв',
#  'мо',
#  'распоряжен',
#  'имеет',
#  'начальн',
#  'довольн',
#  'функциональн',
#  'модел',
#  'суд',
#  'вышеприведен',
#  'таблиц',
#  'взят',
#  'официальн',
#  'документац',
#  'эт',
#  'модел',
#  'должн',
#  'имет',
#  'транзисторн',
#  'выход',
#  'сам',
#  'дел',
#  'отсутств',
#  'реальн',
#  'контроллер',
#  'эт',
#  'ошибк',
#  'документац',
#  'выход',
#  'прост',
#  'заб',
#  'распая',
#  'плат',
#  'сказа',
#  'трудн',
#  'суд',
#  'отсутств',
#  'маркировк',
#  'выход',
#  'корпус',
#  'устройств',
#  'эт',
#  'скор',
#  'ошибк',
#  'документациивс',
#  'контроллер',
#  'линейк',
#  'содержат',
#  'модул',
#  'эт',
#  'либ',
#  'прост',
#  'либ',
#  'продвинут',
#  'модул',
#  'мо',
#  'случа',
#  'эт',
#  'привычн',
#  'нам',
#  'штырев',
#  'антен',
#  'корпус',
#  'эт',
#  'антен',
#  'модул',
#  'компонент',
#  'характеристикич',
#  'порадова',
#  'дава',
#  'познаком',
#  'списк',
#  'компонент',
#  'находя',
#  'борт',
#  'контроллер',
#  'модул',
#  'внешн',
#  'антеннаразь',
#  'карт',
#  'цифров',
#  'вход',
#  'светодиод',
#  'вход',
#  'аналогов',
#  'вход',
#  'винтерфейс',
#  'диспл',
#  'кнопк',
#  'управлен',
#  'передн',
#  'панелимежблочн',
#  'интерфейс',
#  'разь',
#  'программированиякнопк',
#  'индикатор',
#  'налич',
#  'питаниянапряжен',
#  'питан',
#  'вв',
#  'цел',
#  'сказа',
#  'эт',
#  'довольн',
#  'гармоничн',
#  'сбалансирова',
#  'модел',
#  'несложн',
#  'проект',
#  'борт',
#  'присутствова',
#  'транзисторн',
#  'выход',
#  'заявлен',
#  'документац',
#  'все',
#  'хорошон',
#  'учитыв',
#  'имеет',
#  'межблочн',
#  'интерфейс',
#  'функциона',
#  'контроллер',
#  'значительн',
#  'расшир',
#  'соответств',
#  'требован',
#  'ваш',
#  'проектакартин',
#  'дополня',
#  'традицион',
#  'отличн',
#  'дизайн',
#  'корпус',
#  'диспл',
#  'кнопк',
#  'управлен',
#  'светодиодн',
#  'индикатор',
#  'так',
#  'контроллер',
#  'очен',
#  'приятн',
#  'работа',
#  'точн',
#  'испорт',
#  'внешн',
#  'вид',
#  'ваш',
#  'щитк',
#  'автоматик',
#  'разбира',
#  'контроллерест',
#  'контроллер',
#  'одн',
#  'неприятн',
#  'родов',
#  'черт',
#  'практическ',
#  'модел',
#  'редк',
#  'исключен',
#  'очен',
#  'трудн',
#  'разбира',
#  'сказа',
#  'вообщ',
#  'предназнач',
#  'разборк',
#  'процесс',
#  'вскрыт',
#  'корпус',
#  'извлечен',
#  'контроллер',
#  'приход',
#  'сильн',
#  'гнут',
#  'пластмасс',
#  'риску',
#  'е',
#  'слома',
#  'подверга',
#  'механическ',
#  'нагрузк',
#  'сам',
#  'плат',
#  'контроллераприч',
#  'разобра',
#  'контроллер',
#  'трудн',
#  'эт',
#  'дела',
#  'точн',
#  'знаеш',
#  'дела',
#  'например',
#  'врем',
#  'разборк',
#  'извлечен',
#  'плат',
#  'поддон',
#  'мно',
#  'поврежд',
#  'печатн',
#  'дорожк',
#  'кра',
#  'плат',
#  'выбор',
#  'велик',
#  'либ',
#  'риск',
#  'слома',
#  'пластмасс',
#  'корпус',
#  'либ',
#  'риск',
#  'повред',
#  'плат',
#  'контроллера',
#  'существ',
#  'множеств',
#  'контроллер',
#  'котор',
#  'разбира',
#  'легк',
#  'прост',
#  'случа',
#  'контроллер',
#  'главн',
#  'виновник',
#  'пробл',
#  'разборк',
#  'сборк',
#  'явля',
#  'боков',
#  'разь',
#  'расширен',
#  'слишк',
#  'мощн',
#  'фиксатор',
#  'плат',
#  'нижн',
#  'крышк',
#  'корпус',
#  'схемотехникавнутрен',
#  'устройств',
#  'такж',
#  'типичн',
#  'контроллер',
#  'эт',
#  'все',
#  'те',
#  'две',
#  'плат',
#  'соединен',
#  'соб',
#  'двум',
#  'стойк',
#  'штырьк',
#  'соединен',
#  'неразъемн',
#  'захочет',
#  'модернизирова',
#  'значительн',
#  'усил',
#  'хирургическ',
#  'вмешательств',
#  'эт',
#  'сдела',
#  'получитсяахтунг',
#  'обзор',
#  'обзор',
#  'вынужд',
#  'упомина',
#  'ещ',
#  'одн',
#  'родов',
#  'проблем',
#  'качеств',
#  'е',
#  'документац',
#  'эт',
#  'документац',
#  'прост',
#  'ужасн',
#  'одн',
#  'е',
#  'част',
#  'противоречат',
#  'друг',
#  'документац',
#  'противореч',
#  'надпис',
#  'корпус',
#  'контроллер',
#  'вмест',
#  'противоречат',
#  'том',
#  'реальн',
#  'желез',
#  'удивительн',
#  'сам',
#  'желез',
#  'вполн',
#  'адекватн',
#  'нормальн',
#  'работаетвс',
#  'дан',
#  'компонент',
#  'контакт',
#  'распиновк',
#  'т',
#  'д',
#  'обзор',
#  'приход',
#  'проверя',
#  'перепроверя',
#  'луп',
#  'тестер',
#  'поэт',
#  'чтолиб',
#  'подключа',
#  'основан',
#  'дан',
#  'официальн',
#  'документац',
#  'категорическ',
#  'рекоменд',
#  'польз',
#  'проверен',
#  'информац',
#  'статьивнешн',
#  'вид',
#  'назначен',
#  'контакт',
#  'расположен',
#  'индикатор',
#  'модификац',
#  'плат',
#  'контроллераплат',
#  'контроллер',
#  'соедин',
#  'соб',
#  'двум',
#  'групп',
#  'контакт',
#  'кажд',
#  'групп',
#  'содерж',
#  'контакт',
#  'сам',
#  'контакт',
#  'сдела',
#  'неразъемн',
#  'разобра',
#  'контроллер',
#  'выпаив',
#  'соединя',
#  'плат',
#  'перемычк',
#  'штырьк',
#  'нижн',
#  'плат',
#  'содерж',
#  'колодк',
#  'подключен',
#  'цифров',
#  'аналогов',
#  'вход',
#  'питан',
#  'контроллер',
#  'такж',
#  'разь',
#  'интерфейс',
#  'плат',
#  'наход',
#  'электрон',
#  'компонент',
#  'соответств',
#  'подсистемверхн',
#  'плат',
#  'содерж',
#  'микроконтроллер',
#  'модул',
#  'разъем',
#  'подключен',
#  'карт',
#  'выносн',
#  'антен',
#  'межблочн',
#  'интерфейс',
#  'подсист',
#  'чип',
#  'диспл',
#  'управля',
#  'кнопк',
#  'индикаторн',
#  'светодиод',
#  'проч',
#  'элементыпитаниеподсистем',
#  'питан',
#  'состо',
#  'импульсн',
#  'понижа',
#  'регулятор',
#  'напряжен',
#  'линейн',
#  'регулятор',
#  'контроллер',
#  'рассчита',
#  'входн',
#  'напряжен',
#  'работа',
#  'меньш',
#  'напряжениявид',
#  'элемент',
#  'подсистем',
#  'питан',
#  'индуктивн',
#  'диод',
#  'фильтр',
#  'конденсатор',
#  'проч',
#  'элемент',
#  'микросхем',
#  'преобразовател',
#  'спрята',
#  'конденсатор',
#  'индуктивн',
#  'формир',
#  'напряжен',
#  'наход',
#  'верхн',
#  'платечастичн',
#  'запита',
#  'контроллер',
#  'разъем',
#  'дан',
#  'случа',
#  'плат',
#  'установл',
#  'модул',
#  'больш',
#  'пиков',
#  'потреблен',
#  'ток',
#  'поэт',
#  'полноцен',
#  'питан',
#  'контакт',
#  'колодок',
#  'пренебрегатьядр',
#  'качеств',
#  'ядр',
#  'контроллер',
#  'использ',
#  'популярн',
#  'модул',
#  'котор',
#  'располага',
#  'обратн',
#  'сторон',
#  'верхн',
#  'плат',
#  'наход',
#  'линейн',
#  'регулятор',
#  'формир',
#  'напряжен',
#  'питаниядл',
#  'подключен',
#  'компьютер',
#  'программирован',
#  'верхн',
#  'плат',
#  'присутств',
#  'разь',
#  'микросхем',
#  'преобразовател',
#  'такж',
#  'проч',
#  'элемент',
#  'кнопк',
#  'корпус',
#  'ряд',
#  'разь',
#  'отверст',
#  'е',
#  'нажатияцифров',
#  'входымодел',
#  'имеет',
#  'цифров',
#  'вход',
#  'подключен',
#  'две',
#  'микросхем',
#  'содержа',
#  'кажд',
#  'оптопар',
#  'возможн',
#  'вариант',
#  'подключен',
#  'плюс',
#  'контакт',
#  'минус',
#  'терминолог',
#  'производител',
#  'аналогов',
#  'вход',
#  'имеет',
#  'аналогов',
#  'вход',
#  'реализова',
#  'помощ',
#  'микросхем',
#  'битн',
#  'аналогоцифров',
#  'преобразовател',
#  'интерфейсомрасположен',
#  'плат',
#  'подсистем',
#  'аналогоцифров',
#  'преобразовател',
#  'чип',
#  'распая',
#  'обратн',
#  'сторон',
#  'плат',
#  'адрес',
#  'шин',
#  'транзисторн',
#  'выходытранзисторн',
#  'выход',
#  'плат',
#  'прост',
#  'вмест',
#  'микросхем',
#  'хот',
#  'суд',
#  'официальн',
#  'информац',
#  'сайт',
#  'производител',
#  'должн',
#  'бытьн',
#  'фот',
#  'отмеч',
#  'мест',
#  'котор',
#  'должн',
#  'распая',
#  'элемент',
#  'подсистем',
#  'транзисторн',
#  'выход',
#  'почемут',
#  'распая',
#  'особ',
#  'желан',
#  'элемент',
#  'допая',
#  'самостоятельн',
#  'модул',
#  'основн',
#  'фишк',
#  'контроллер',
#  'модул',
#  'установл',
#  'обратн',
#  'сторон',
#  'верхн',
#  'плат',
#  'вмест',
#  'разъем',
#  'карт',
#  'внешн',
#  'антенныпр',
#  'работ',
#  'подсистем',
#  'пок',
#  'мог',
#  'сказа',
#  'определен',
#  'кром',
#  'модул',
#  'отзыва',
#  'команд',
#  'перв',
#  'приближен',
#  'ведет',
#  'нормальн',
#  'ожида',
#  'скор',
#  'подсистем',
#  'никак',
#  'пробл',
#  'эт',
#  'покажут',
#  'дальн',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализова',
#  'типов',
#  'контроллер',
#  'схем',
#  'чип',
#  'трансивер',
#  'микросхем',
#  'располага',
#  'нижн',
#  'плат',
#  'контроллер',
#  'ряд',
#  'соответств',
#  'разъем',
#  'интерфейс',
#  'автоматическ',
#  'управлен',
#  'режим',
#  'приемапередач',
#  'отсутств',
#  'микроконтроллер',
#  'подключ',
#  'пин',
#  'дисплейв',
#  'вывод',
#  'информац',
#  'использ',
#  'диспл',
#  'значен',
#  'факт',
#  'трудн',
#  'переоцен',
#  'точн',
#  'найдет',
#  'примен',
#  'ваш',
#  'проект',
#  'адрес',
#  'диспле',
#  'шин',
#  'кнопк',
#  'кнопк',
#  'хитр',
#  'подключен',
#  'одн',
#  'эт',
#  'подключен',
#  'позволя',
#  'отслежива',
#  'нажат',
#  'кнопок',
#  'определя',
#  'сочетаниесхем',
#  'подключен',
#  'кнопок',
#  'межблочн',
#  'интерфейсконтроллер',
#  'линейк',
#  'содержат',
#  'межблочн',
#  'интерфейс',
#  'полезн',
#  'дополнен',
#  'котор',
#  'позволя',
#  'значительн',
#  'расшир',
#  'базов',
#  'возможн',
#  'качеств',
#  'межблочн',
#  'интерфейс',
#  'использ',
#  'контактн',
#  'шлейфов',
#  'соединениениж',
#  'привед',
#  'распиновк',
#  'межблочн',
#  'разъем',
#  'некотор',
#  'вопрос',
#  'вызыва',
#  'пин',
#  'воперв',
#  'назначен',
#  'соответств',
#  'различн',
#  'сер',
#  'вовтор',
#  'согласн',
#  'официальн',
#  'документац',
#  'вообщ',
#  'подключ',
#  'зна',
#  'качеств',
#  'документац',
#  'эт',
#  'нужн',
#  'проверя',
#  'отдельносветодиодн',
#  'индикаторысветодиодн',
#  'индикатор',
#  'состоян',
#  'вход',
#  'шт',
#  'светодиод',
#  'налич',
#  'напряжен',
#  'питан',
#  'фот',
#  'видн',
#  'светодиод',
#  'цифров',
#  'выход',
#  'распая',
#  'распиновкараспиновк',
#  'контроллер',
#  'желт',
#  'цвет',
#  'помеч',
#  'контакт',
#  'выведен',
#  'межблочн',
#  'разь',
#  'видн',
#  'множеств',
#  'оста',
#  'незадействова',
#  'будут',
#  'использова',
#  'старш',
#  'модел',
#  'сер',
#  'больш',
#  'количеств',
#  'подключен',
#  'компонент',
#  'заключен',
#  'качеств',
#  'заключен',
#  'сказа',
#  'эт',
#  'довольн',
#  'интересн',
#  'модел',
#  'микроконтроллер',
#  'налич',
#  'модул',
#  'значительн',
#  'расширя',
#  'е',
#  'возможн',
#  'создан',
#  'проект',
#  'сто',
#  'такж',
#  'отмет',
#  'модел',
#  'имеет',
#  'разь',
#  'подключен',
#  'дополнительн',
#  'блок',
#  'позволя',
#  'ещ',
#  'расшир',
#  'диапазон',
#  'решен',
#  'е',
#  'основ']

# %% [markdown]
# 6. Лемматизация

# %%
from nltk.stem import WordNetLemmatizer

# %%
wn = nltk.WordNetLemmatizer()
def lemmatizing(text):
    tokenized_text = [wn.lemmatize(word) for word in text]
    return tokenized_text

# %%
t2 = lemmatizing(t)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# C:\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      82                 try:
# ---> 83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
#
# C:\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet.zip/wordnet/
#
#   Searched in:
#     - 'C:\\Users\\МОиБД/nltk_data'
#     - 'C:\\anaconda3\\nltk_data'
#     - 'C:\\anaconda3\\share\\nltk_data'
#     - 'C:\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\МОиБД\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************
#
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-68-59b0e8f31e61> in <module>
# ----> 1 t2 = lemmatizing(t)
#
# <ipython-input-67-0c31989d3d75> in lemmatizing(text)
#       1 wn = nltk.WordNetLemmatizer()
#       2 def lemmatizing(text):
# ----> 3     tokenized_text = [wn.lemmatize(word) for word in text]
#       4     return tokenized_text
#
# <ipython-input-67-0c31989d3d75> in <listcomp>(.0)
#       1 wn = nltk.WordNetLemmatizer()
#       2 def lemmatizing(text):
# ----> 3     tokenized_text = [wn.lemmatize(word) for word in text]
#       4     return tokenized_text
#
# C:\anaconda3\lib\site-packages\nltk\stem\wordnet.py in lemmatize(self, word, pos)
#      36
#      37     def lemmatize(self, word, pos=NOUN):
# ---> 38         lemmas = wordnet._morphy(word, pos)
#      39         return min(lemmas, key=len) if lemmas else word
#      40
#
# C:\anaconda3\lib\site-packages\nltk\corpus\util.py in __getattr__(self, attr)
#     118             raise AttributeError("LazyCorpusLoader object has no attribute '__bases__'")
#     119
# --> 120         self.__load()
#     121         # This looks circular, but its not, since __load() changes our
#     122         # __class__ to something new:
#
# C:\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      83                     root = nltk.data.find("{}/{}".format(self.subdir, zip_name))
#      84                 except LookupError:
# ---> 85                     raise e
#      86
#      87         # Load the corpus.
#
# C:\anaconda3\lib\site-packages\nltk\corpus\util.py in __load(self)
#      78         else:
#      79             try:
# ---> 80                 root = nltk.data.find("{}/{}".format(self.subdir, self.__name))
#      81             except LookupError as e:
#      82                 try:
#
# C:\anaconda3\lib\site-packages\nltk\data.py in find(resource_name, paths)
#     581     sep = "*" * 70
#     582     resource_not_found = "\n%s\n%s\n%s\n" % (sep, msg, sep)
# --> 583     raise LookupError(resource_not_found)
#     584
#     585
#
# LookupError:
# **********************************************************************
#   Resource wordnet not found.
#   Please use the NLTK Downloader to obtain the resource:
#
#   >>> import nltk
#   >>> nltk.download('wordnet')
#
#   For more information see: https://www.nltk.org/data.html
#
#   Attempted to load corpora/wordnet
#
#   Searched in:
#     - 'C:\\Users\\МОиБД/nltk_data'
#     - 'C:\\anaconda3\\nltk_data'
#     - 'C:\\anaconda3\\share\\nltk_data'
#     - 'C:\\anaconda3\\lib\\nltk_data'
#     - 'C:\\Users\\МОиБД\\AppData\\Roaming\\nltk_data'
#     - 'C:\\nltk_data'
#     - 'D:\\nltk_data'
#     - 'E:\\nltk_data'
# **********************************************************************

# %%
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\МОиБД\AppData\Roaming\nltk_data...
# True

# %%
t2 = lemmatizing(t)

# %%
t2
# Out:
# ['своём',
#  'блоге',
#  'рассмотрел',
#  'устройство',
#  'назначение',
#  'контроллеров',
#  'обойдены',
#  'вниманием',
#  'оказались',
#  'контроллеры',
#  'линейки',
#  'имеющие',
#  'соответствующие',
#  'модули',
#  'своём',
#  'бортукак',
#  'понимаете',
#  'наличие',
#  'модуля',
#  'является',
#  'существенным',
#  'дополнением',
#  'значительно',
#  'расширяет',
#  'возможности',
#  'контроллера',
#  'посылать',
#  'принимать',
#  'информационные',
#  'управляющие',
#  'организовать',
#  'резервный',
#  'независимый',
#  'вашей',
#  'инфраструктуры',
#  'канал',
#  'связи',
#  'т',
#  'дв',
#  'статье',
#  'рассмотрю',
#  'модель',
#  'которая',
#  'кроме',
#  'модуля',
#  'содержит',
#  'цифровые',
#  'аналоговые',
#  'входы',
#  'интерфейс',
#  'прочие',
#  'возможности',
#  'делает',
#  'контроллер',
#  'интересным',
#  'решением',
#  'создания',
#  'ваших',
#  'проектов',
#  'автоматизации',
#  'семейство',
#  'контроллеры',
#  'линейки',
#  'имеют',
#  'качестве',
#  'ядра',
#  'модуль',
#  'мб',
#  'т',
#  'д',
#  'позволяет',
#  'решать',
#  'довольно',
#  'тяжёлые',
#  'вычислительные',
#  'задачи',
#  'поддерживать',
#  'беспроводную',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрованием',
#  'данных',
#  'т',
#  'дбольшинство',
#  'моделей',
#  'контроллеров',
#  'линейки',
#  'имеют',
#  'модуль',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панели',
#  'корпуса',
#  'межблочный',
#  'интерфейс',
#  'цифровые',
#  'опторазвязанные',
#  'входы',
#  'остальные',
#  'характеристики',
#  'отличаются',
#  'составить',
#  'представление',
#  'следующей',
#  'таблицемодель',
#  'имеющаяся',
#  'моём',
#  'распоряжении',
#  'выделена',
#  'серым',
#  'фономв',
#  'моём',
#  'распоряжении',
#  'имеется',
#  'начальная',
#  'довольно',
#  'функциональная',
#  'модель',
#  'судя',
#  'вышеприведённой',
#  'таблице',
#  'взятой',
#  'официальной',
#  'документации',
#  'эта',
#  'модель',
#  'должна',
#  'иметь',
#  'транзисторных',
#  'выхода',
#  'самом',
#  'деле',
#  'отсутствуют',
#  'реальном',
#  'контроллере',
#  'это',
#  'ошибка',
#  'документации',
#  'выходы',
#  'просто',
#  'забыли',
#  'распаять',
#  'плате',
#  'сказать',
#  'трудно',
#  'судя',
#  'отсутствию',
#  'маркировки',
#  'выходов',
#  'корпусе',
#  'устройства',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллеры',
#  'линейки',
#  'содержат',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинутый',
#  'модуль',
#  'моём',
#  'случае',
#  'это',
#  'привычный',
#  'нам',
#  'штыревая',
#  'антенна',
#  'корпусе',
#  'это',
#  'антенна',
#  'модуля',
#  'компоненты',
#  'характеристикичем',
#  'порадовала',
#  'давайте',
#  'познакомимся',
#  'списком',
#  'компонентов',
#  'находящихся',
#  'борту',
#  'контроллер',
#  'модуль',
#  'внешняя',
#  'антеннаразъём',
#  'карт',
#  'цифровых',
#  'входов',
#  'светодиодов',
#  'входов',
#  'аналоговых',
#  'входа',
#  'винтерфейс',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'передней',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличия',
#  'питаниянапряжение',
#  'питания',
#  'вв',
#  'целом',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничная',
#  'сбалансированная',
#  'модель',
#  'несложных',
#  'проектов',
#  'борту',
#  'присутствовали',
#  'транзисторные',
#  'выходы',
#  'заявленные',
#  'документации',
#  'всё',
#  'хорошоно',
#  'учитывая',
#  'имеет',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллера',
#  'значительно',
#  'расширить',
#  'соответствии',
#  'требованиями',
#  'вашего',
#  'проектакартину',
#  'дополняют',
#  'традиционные',
#  'отличный',
#  'дизайн',
#  'корпуса',
#  'дисплей',
#  'кнопки',
#  'управления',
#  'светодиодные',
#  'индикаторы',
#  'таким',
#  'контроллером',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортит',
#  'внешний',
#  'вид',
#  'вашего',
#  'щитка',
#  'автоматики',
#  'разбираем',
#  'контроллересть',
#  'контроллеров',
#  'одна',
#  'неприятная',
#  'родовая',
#  'черта',
#  'практически',
#  'модели',
#  'редкими',
#  'исключениями',
#  'очень',
#  'трудно',
#  'разбираются',
#  'сказать',
#  'вообще',
#  'предназначены',
#  'разборки',
#  'процессе',
#  'вскрытия',
#  'корпуса',
#  'извлечения',
#  'контроллера',
#  'приходится',
#  'сильно',
#  'гнуть',
#  'пластмассу',
#  'рискуя',
#  'её',
#  'сломать',
#  'подвергать',
#  'механическим',
#  'нагрузкам',
#  'сами',
#  'платы',
#  'контроллерапричём',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делал',
#  'точно',
#  'знаешь',
#  'делаешь',
#  'например',
#  'время',
#  'разборки',
#  'извлечения',
#  'платы',
#  'поддона',
#  'мной',
#  'повреждена',
#  'печатная',
#  'дорожка',
#  'края',
#  'платы',
#  'выбор',
#  'велик',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмассу',
#  'корпуса',
#  'либо',
#  'риск',
#  'повредить',
#  'плату',
#  'контроллераа',
#  'существует',
#  'множество',
#  'контроллеров',
#  'которые',
#  'разбираются',
#  'легко',
#  'простов',
#  'случае',
#  'контроллеров',
#  'главными',
#  'виновниками',
#  'проблем',
#  'разборкой',
#  'сборкой',
#  'являются',
#  'боковой',
#  'разъём',
#  'расширения',
#  'слишком',
#  'мощные',
#  'фиксаторы',
#  'платы',
#  'нижней',
#  'крышке',
#  'корпуса',
#  'схемотехникавнутреннее',
#  'устройство',
#  'также',
#  'типично',
#  'контроллеров',
#  'это',
#  'всё',
#  'те',
#  'две',
#  'платы',
#  'соединённые',
#  'собой',
#  'двумя',
#  'стойками',
#  'штырьков',
#  'соединения',
#  'неразъёмные',
#  'захочется',
#  'модернизировать',
#  'значительных',
#  'усилий',
#  'хирургических',
#  'вмешательств',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзора',
#  'обзор',
#  'вынужден',
#  'упоминать',
#  'ещё',
#  'одной',
#  'родовой',
#  'проблеме',
#  'качестве',
#  'её',
#  'документации',
#  'эта',
#  'документация',
#  'просто',
#  'ужасна',
#  'одни',
#  'её',
#  'части',
#  'противоречат',
#  'другим',
#  'документация',
#  'противоречит',
#  'надписям',
#  'корпусе',
#  'контроллера',
#  'вместе',
#  'противоречат',
#  'тому',
#  'реально',
#  'железе',
#  'удивительно',
#  'само',
#  'железо',
#  'вполне',
#  'адекватное',
#  'нормально',
#  'работаетвсе',
#  'данные',
#  'компонентам',
#  'контактам',
#  'распиновкам',
#  'т',
#  'д',
#  'обзора',
#  'приходилось',
#  'проверять',
#  'перепроверять',
#  'лупой',
#  'тестером',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основании',
#  'данных',
#  'официальной',
#  'документации',
#  'категорически',
#  'рекомендуется',
#  'пользуйтесь',
#  'проверенной',
#  'информацией',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контактов',
#  'расположение',
#  'индикаторов',
#  'модификации',
#  'платы',
#  'контроллераплаты',
#  'контроллера',
#  'соединены',
#  'собой',
#  'двумя',
#  'группами',
#  'контактов',
#  'каждая',
#  'группа',
#  'содержит',
#  'контактов',
#  'сами',
#  'контакты',
#  'сделаны',
#  'неразъёмными',
#  'разобрать',
#  'контроллер',
#  'выпаивая',
#  'соединяющие',
#  'платы',
#  'перемычки',
#  'штырьки',
#  'нижняя',
#  'плата',
#  'содержит',
#  'колодки',
#  'подключения',
#  'цифровых',
#  'аналоговых',
#  'входов',
#  'питания',
#  'контроллера',
#  'также',
#  'разъём',
#  'интерфейса',
#  'плате',
#  'находятся',
#  'электронные',
#  'компоненты',
#  'соответствующих',
#  'подсистемверхняя',
#  'плата',
#  'содержит',
#  'микроконтроллер',
#  'модуль',
#  'разъёмы',
#  'подключения',
#  'карты',
#  'выносной',
#  'антенны',
#  'межблочный',
#  'интерфейс',
#  'подсистему',
#  'чипе',
#  'дисплей',
#  'управляющие',
#  'кнопки',
#  'индикаторные',
#  'светодиоды',
#  'прочие',
#  'элементыпитаниеподсистема',
#  'питания',
#  'состоит',
#  'импульсного',
#  'понижающего',
#  'регулятора',
#  'напряжения',
#  'линейного',
#  'регулятора',
#  'контроллер',
#  'рассчитан',
#  'входное',
#  'напряжение',
#  'работает',
#  'меньшего',
#  'напряжениявид',
#  'элементы',
#  'подсистемы',
#  'питания',
#  'индуктивность',
#  'диод',
#  'фильтрующие',
#  'конденсаторы',
#  'прочие',
#  'элементы',
#  'микросхема',
#  'преобразователя',
#  'спряталась',
#  'конденсатором',
#  'индуктивностью',
#  'формирующий',
#  'напряжение',
#  'находится',
#  'верхней',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъёма',
#  'данном',
#  'случае',
#  'плате',
#  'установлен',
#  'модуль',
#  'большим',
#  'пиковым',
#  'потреблением',
#  'тока',
#  'поэтому',
#  'полноценным',
#  'питанием',
#  'контакты',
#  'колодок',
#  'пренебрегатьядро',
#  'качестве',
#  'ядра',
#  'контроллер',
#  'использует',
#  'популярный',
#  'модуль',
#  'который',
#  'располагается',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'находится',
#  'линейный',
#  'регулятор',
#  'формирующий',
#  'напряжение',
#  'питаниядля',
#  'подключения',
#  'компьютеру',
#  'программирования',
#  'верхней',
#  'плате',
#  'присутствует',
#  'разъём',
#  'микросхема',
#  'преобразователя',
#  'также',
#  'прочие',
#  'элементы',
#  'кнопка',
#  'корпусе',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровые',
#  'входымодель',
#  'имеет',
#  'цифровых',
#  'входов',
#  'подключённых',
#  'две',
#  'микросхемы',
#  'содержащие',
#  'каждая',
#  'оптопары',
#  'возможны',
#  'варианта',
#  'подключения',
#  'плюсом',
#  'контакт',
#  'минусом',
#  'терминологии',
#  'производителя',
#  'аналоговые',
#  'входы',
#  'имеет',
#  'аналоговых',
#  'входа',
#  'реализованных',
#  'помощи',
#  'микросхемы',
#  'битного',
#  'аналогоцифрового',
#  'преобразователя',
#  'интерфейсомрасположение',
#  'плате',
#  'подсистемы',
#  'аналогоцифрового',
#  'преобразователя',
#  'чип',
#  'распаян',
#  'обратной',
#  'стороне',
#  'платы',
#  'адрес',
#  'шине',
#  'транзисторные',
#  'выходытранзисторных',
#  'выходов',
#  'плате',
#  'просто',
#  'вместе',
#  'микросхемой',
#  'хотя',
#  'судя',
#  'официальной',
#  'информации',
#  'сайте',
#  'производителя',
#  'должны',
#  'бытьна',
#  'фото',
#  'отмечено',
#  'место',
#  'котором',
#  'должны',
#  'распаяны',
#  'элементы',
#  'подсистемы',
#  'транзисторных',
#  'выходов',
#  'почемуто',
#  'распаяны',
#  'особом',
#  'желании',
#  'элементы',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основная',
#  'фишка',
#  'контроллера',
#  'модуль',
#  'установлен',
#  'обратной',
#  'стороне',
#  'верхней',
#  'платы',
#  'вместе',
#  'разъёмами',
#  'карты',
#  'внешней',
#  'антенныпро',
#  'работу',
#  'подсистемы',
#  'пока',
#  'могу',
#  'сказать',
#  'определённого',
#  'кроме',
#  'модуль',
#  'отзывается',
#  'команды',
#  'первом',
#  'приближении',
#  'ведёт',
#  'нормально',
#  'ожидалось',
#  'скорее',
#  'подсистемой',
#  'никаких',
#  'проблем',
#  'это',
#  'покажут',
#  'дальнейшие',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализован',
#  'типовой',
#  'контроллеров',
#  'схеме',
#  'чипе',
#  'трансивера',
#  'микросхема',
#  'располагается',
#  'нижней',
#  'плате',
#  'контроллера',
#  'рядом',
#  'соответствующими',
#  'разъёмами',
#  'интерфейса',
#  'автоматическое',
#  'управление',
#  'режимами',
#  'приёмапередачи',
#  'отсутствует',
#  'микроконтроллеру',
#  'подключен',
#  'пин',
#  'дисплейв',
#  'вывода',
#  'информации',
#  'используется',
#  'дисплей',
#  'значение',
#  'факта',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найдёте',
#  'применить',
#  'ваших',
#  'проектах',
#  'адрес',
#  'дисплея',
#  'шине',
#  'кнопки',
#  'кнопки',
#  'хитрым',
#  'подключением',
#  'одному',
#  'это',
#  'подключение',
#  'позволяет',
#  'отслеживать',
#  'нажатие',
#  'кнопок',
#  'определять',
#  'сочетаниесхема',
#  'подключения',
#  'кнопок',
#  'межблочный',
#  'интерфейсконтроллеры',
#  'линейки',
#  'содержат',
#  'межблочный',
#  'интерфейс',
#  'полезное',
#  'дополнение',
#  'которое',
#  'позволяет',
#  'значительно',
#  'расширить',
#  'базовые',
#  'возможности',
#  'качестве',
#  'межблочного',
#  'интерфейса',
#  'используется',
#  'контактное',
#  'шлейфовое',
#  'соединениениже',
#  'приведена',
#  'распиновка',
#  'межблочного',
#  'разъёма',
#  'некоторые',
#  'вопросы',
#  'вызывают',
#  'пины',
#  'вопервых',
#  'назначение',
#  'соответствует',
#  'различных',
#  'серий',
#  'вовторых',
#  'согласно',
#  'официальной',
#  'документации',
#  'вообще',
#  'подключены',
#  'зная',
#  'качество',
#  'документации',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодные',
#  'индикаторысветодиодные',
#  'индикаторы',
#  'состояния',
#  'входов',
#  'шт',
#  'светодиод',
#  'наличия',
#  'напряжения',
#  'питания',
#  'фото',
#  'видно',
#  'светодиода',
#  'цифровых',
#  'выходов',
#  'распаяны',
#  'распиновкараспиновка',
#  'контроллера',
#  'желтым',
#  'цветом',
#  'помечены',
#  'контакты',
#  'выведенные',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'осталось',
#  'незадействованными',
#  'будут',
#  'использоваться',
#  'старших',
#  'моделях',
#  'серии',
#  'большим',
#  'количеством',
#  'подключённых',
#  'компонентов',
#  'заключениев',
#  'качестве',
#  'заключения',
#  'сказать',
#  'это',
#  'довольно',
#  'интересная',
#  'модель',
#  'микроконтроллере',
#  'наличие',
#  'модуля',
#  'значительно',
#  'расширяет',
#  'её',
#  'возможности',
#  'создания',
#  'проектов',
#  'стоит',
#  'также',
#  'отметить',
#  'модель',
#  'имеет',
#  'разъём',
#  'подключения',
#  'дополнительных',
#  'блоков',
#  'позволяет',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решений',
#  'её',
#  'основе']

# %%
import pymorphy2

# %%
morph = pymorphy2.MorphAnalyzer()

# %%
def lemmatize(text):
    res = list()
    for word in text:
        p = morph.parse(word)[0]
        res.append(p.normal_form)

    return res

# %%
t4 = lemmatize(t)

# %%
t4
# Out:
# ['свой',
#  'блог',
#  'рассмотреть',
#  'устройство',
#  'назначение',
#  'контроллер',
#  'обойти',
#  'внимание',
#  'оказаться',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'соответствующий',
#  'модуль',
#  'свой',
#  'бортукак',
#  'понимать',
#  'наличие',
#  'модуль',
#  'являться',
#  'существенный',
#  'дополнение',
#  'значительно',
#  'расширять',
#  'возможность',
#  'контроллер',
#  'посылать',
#  'принимать',
#  'информационный',
#  'управлять',
#  'организовать',
#  'резервный',
#  'независимый',
#  'ваш',
#  'инфраструктура',
#  'канал',
#  'связь',
#  'так',
#  'дв',
#  'статья',
#  'рассмотреть',
#  'модель',
#  'который',
#  'кроме',
#  'модуль',
#  'содержать',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'интерфейс',
#  'прочий',
#  'возможность',
#  'делать',
#  'контроллер',
#  'интересный',
#  'решение',
#  'создание',
#  'ваш',
#  'проект',
#  'автоматизация',
#  'семейство',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'качество',
#  'ядро',
#  'модуль',
#  'мб',
#  'так',
#  'далее',
#  'позволять',
#  'решать',
#  'довольно',
#  'тяжёлый',
#  'вычислительный',
#  'задача',
#  'поддерживать',
#  'беспроводный',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрование',
#  'данные',
#  'так',
#  'дбольшинство',
#  'модель',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'модуль',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панель',
#  'корпус',
#  'межблочный',
#  'интерфейс',
#  'цифровой',
#  'опторазвязать',
#  'вход',
#  'остальной',
#  'характеристика',
#  'отличаться',
#  'составить',
#  'представление',
#  'следующий',
#  'таблицемодель',
#  'иметься',
#  'мой',
#  'распоряжение',
#  'выделить',
#  'серый',
#  'фономть',
#  'мой',
#  'распоряжение',
#  'иметься',
#  'начальный',
#  'довольно',
#  'функциональный',
#  'модель',
#  'судить',
#  'вышеприведённый',
#  'таблица',
#  'взять',
#  'официальный',
#  'документация',
#  'этот',
#  'модель',
#  'должный',
#  'иметь',
#  'транзисторный',
#  'выход',
#  'сам',
#  'дело',
#  'отсутствовать',
#  'реальный',
#  'контроллер',
#  'это',
#  'ошибка',
#  'документация',
#  'выход',
#  'просто',
#  'забыть',
#  'распаять',
#  'плата',
#  'сказать',
#  'трудно',
#  'судить',
#  'отсутствие',
#  'маркировка',
#  'выход',
#  'корпус',
#  'устройство',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллер',
#  'линейка',
#  'содержать',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинуть',
#  'модуль',
#  'мой',
#  'случай',
#  'это',
#  'привычный',
#  'мы',
#  'штыревой',
#  'антенна',
#  'корпус',
#  'это',
#  'антенна',
#  'модуль',
#  'компонент',
#  'характеристикич',
#  'порадовать',
#  'давать',
#  'познакомиться',
#  'список',
#  'компонент',
#  'находиться',
#  'борт',
#  'контроллер',
#  'модуль',
#  'внешний',
#  'антеннаразъём',
#  'карта',
#  'цифровой',
#  'вход',
#  'светодиод',
#  'вход',
#  'аналоговый',
#  'вход',
#  'винтерфейс',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличие',
#  'питаниянапряжение',
#  'питание',
#  'век',
#  'целое',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничный',
#  'сбалансированный',
#  'модель',
#  'несложный',
#  'проект',
#  'борт',
#  'присутствовать',
#  'транзисторный',
#  'выход',
#  'заявить',
#  'документация',
#  'всё',
#  'хорошоно',
#  'учитывать',
#  'иметь',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллер',
#  'значительно',
#  'расширить',
#  'соответствие',
#  'требование',
#  'ваш',
#  'проектакартина',
#  'дополнять',
#  'традиционный',
#  'отличный',
#  'дизайн',
#  'корпус',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'светодиодный',
#  'индикатор',
#  'такой',
#  'контроллер',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортить',
#  'внешний',
#  'вид',
#  'ваш',
#  'щиток',
#  'автоматика',
#  'разбирать',
#  'контроллербыть',
#  'контроллер',
#  'один',
#  'неприятный',
#  'родовой',
#  'черта',
#  'практически',
#  'модель',
#  'редкий',
#  'исключение',
#  'очень',
#  'трудно',
#  'разбираться',
#  'сказать',
#  'вообще',
#  'предназначить',
#  'разборка',
#  'процесс',
#  'вскрытие',
#  'корпус',
#  'извлечение',
#  'контроллер',
#  'приходиться',
#  'сильно',
#  'гнуть',
#  'пластмасса',
#  'рисковать',
#  'её',
#  'сломать',
#  'подвергать',
#  'механический',
#  'нагрузка',
#  'сам',
#  'плата',
#  'контроллерапричь',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делать',
#  'точно',
#  'знать',
#  'делать',
#  'например',
#  'время',
#  'разборка',
#  'извлечение',
#  'плата',
#  'поддон',
#  'я',
#  'повредить',
#  'печатный',
#  'дорожка',
#  'край',
#  'плата',
#  'выбор',
#  'большой',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмасса',
#  'корпус',
#  'либо',
#  'риск',
#  'повредить',
#  'плата',
#  'контроллераа',
#  'существовать',
#  'множество',
#  'контроллер',
#  'который',
#  'разбираться',
#  'легко',
#  'простов',
#  'случай',
#  'контроллер',
#  'главный',
#  'виновник',
#  'проблема',
#  'разборка',
#  'сборка',
#  'являться',
#  'боков',
#  'разъём',
#  'расширение',
#  'слишком',
#  'мощный',
#  'фиксатор',
#  'плата',
#  'нижний',
#  'крышка',
#  'корпус',
#  'схемотехникавнутренный',
#  'устройство',
#  'также',
#  'типично',
#  'контроллер',
#  'это',
#  'всё',
#  'тот',
#  'два',
#  'плата',
#  'соединить',
#  'себя',
#  'два',
#  'стойка',
#  'штырёк',
#  'соединение',
#  'неразъёмный',
#  'захотеться',
#  'модернизировать',
#  'значительный',
#  'усилие',
#  'хирургический',
#  'вмешательство',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзор',
#  'обзор',
#  'вынудить',
#  'упоминать',
#  'ещё',
#  'один',
#  'родовой',
#  'проблема',
#  'качество',
#  'её',
#  'документация',
#  'этот',
#  'документация',
#  'просто',
#  'ужасный',
#  'один',
#  'её',
#  'часть',
#  'противоречить',
#  'другой',
#  'документация',
#  'противоречить',
#  'надпись',
#  'корпус',
#  'контроллер',
#  'вместе',
#  'противоречить',
#  'тот',
#  'реально',
#  'железа',
#  'удивительно',
#  'сам',
#  'железо',
#  'вполне',
#  'адекватный',
#  'нормально',
#  'работаетвсе',
#  'дать',
#  'компонент',
#  'контакт',
#  'распиновка',
#  'так',
#  'далее',
#  'обзор',
#  'приходиться',
#  'проверять',
#  'перепроверять',
#  'лупа',
#  'тестер',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основание',
#  'данные',
#  'официальный',
#  'документация',
#  'категорически',
#  'рекомендоваться',
#  'пользоваться',
#  'проверить',
#  'информация',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контакт',
#  'расположение',
#  'индикатор',
#  'модификация',
#  'плата',
#  'контроллераплата',
#  'контроллер',
#  'соединить',
#  'себя',
#  'два',
#  'группа',
#  'контакт',
#  'каждый',
#  'группа',
#  'содержать',
#  'контакт',
#  'сам',
#  'контакт',
#  'сделать',
#  'неразъёмный',
#  'разобрать',
#  'контроллер',
#  'выпаивать',
#  'соединять',
#  'плата',
#  'перемычка',
#  'штырёк',
#  'нижний',
#  'плата',
#  'содержать',
#  'колодка',
#  'подключение',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'питание',
#  'контроллер',
#  'также',
#  'разъём',
#  'интерфейс',
#  'плата',
#  'находиться',
#  'электронный',
#  'компонент',
#  'соответствующий',
#  'подсистемверхнять',
#  'плата',
#  'содержать',
#  'микроконтроллер',
#  'модуль',
#  'разъём',
#  'подключение',
#  'карта',
#  'выносной',
#  'антенна',
#  'межблочный',
#  'интерфейс',
#  'подсистема',
#  'чип',
#  'дисплей',
#  'управлять',
#  'кнопка',
#  'индикаторный',
#  'светодиод',
#  'прочий',
#  'элементыпитаниеподсистема',
#  'питание',
#  'состоять',
#  'импульсный',
#  'понижать',
#  'регулятор',
#  'напряжение',
#  'линейный',
#  'регулятор',
#  'контроллер',
#  'рассчитать',
#  'входной',
#  'напряжение',
#  'работать',
#  'малый',
#  'напряжениявид',
#  'элемент',
#  'подсистема',
#  'питание',
#  'индуктивность',
#  'диод',
#  'фильтровать',
#  'конденсатор',
#  'прочий',
#  'элемент',
#  'микросхема',
#  'преобразователь',
#  'спрятаться',
#  'конденсатор',
#  'индуктивность',
#  'формировать',
#  'напряжение',
#  'находиться',
#  'верхний',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъём',
#  'данный',
#  'случай',
#  'плата',
#  'установить',
#  'модуль',
#  'больший',
#  'пиковый',
#  'потребление',
#  'ток',
#  'поэтому',
#  'полноценный',
#  'питание',
#  'контакт',
#  'колодка',
#  'пренебрегатьядро',
#  'качество',
#  'ядро',
#  'контроллер',
#  'использовать',
#  'популярный',
#  'модуль',
#  'который',
#  'располагаться',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'находиться',
#  'линейный',
#  'регулятор',
#  'формировать',
#  'напряжение',
#  'питаниядлить',
#  'подключение',
#  'компьютер',
#  'программирование',
#  'верхний',
#  'плата',
#  'присутствовать',
#  'разъём',
#  'микросхема',
#  'преобразователь',
#  'также',
#  'прочий',
#  'элемент',
#  'кнопка',
#  'корпус',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровый',
#  'входымодель',
#  'иметь',
#  'цифровой',
#  'вход',
#  'подключить',
#  'два',
#  'микросхема',
#  'содержать',
#  'каждый',
#  'оптопара',
#  'возможный',
#  'вариант',
#  'подключение',
#  'плюс',
#  'контакт',
#  'минус',
#  'терминология',
#  'производитель',
#  'аналоговый',
#  'вход',
#  'иметь',
#  'аналоговый',
#  'вход',
#  'реализовать',
#  'помощь',
#  'микросхема',
#  'битный',
#  'аналогоцифровый',
#  'преобразователь',
#  'интерфейсомрасположение',
#  'плата',
#  'подсистема',
#  'аналогоцифровый',
#  'преобразователь',
#  'чип',
#  'распаять',
#  'обратный',
#  'сторона',
#  'плата',
#  'адрес',
#  'шина',
#  'транзисторный',
#  'выходытранзисторный',
#  'выход',
#  'плата',
#  'просто',
#  'вместе',
#  'микросхема',
#  'хотя',
#  'судить',
#  'официальный',
#  'информация',
#  'сайт',
#  'производитель',
#  'должный',
#  'бытьный',
#  'фото',
#  'отметить',
#  'место',
#  'который',
#  'должный',
#  'распаять',
#  'элемент',
#  'подсистема',
#  'транзисторный',
#  'выход',
#  'почемуть',
#  'распаять',
#  'особый',
#  'желание',
#  'элемент',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основный',
#  'фишка',
#  'контроллер',
#  'модуль',
#  'установить',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'вместе',
#  'разъём',
#  'карта',
#  'внешний',
#  'антенныпро',
#  'работа',
#  'подсистема',
#  'пока',
#  'мочь',
#  'сказать',
#  'определённый',
#  'кроме',
#  'модуль',
#  'отзываться',
#  'команда',
#  'первый',
#  'приближение',
#  'вести',
#  'нормально',
#  'ожидаться',
#  'скорее',
#  'подсистема',
#  'никакой',
#  'проблема',
#  'это',
#  'показать',
#  'дальнейший',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализовать',
#  'типовой',
#  'контроллер',
#  'схема',
#  'чип',
#  'трансивер',
#  'микросхема',
#  'располагаться',
#  'нижний',
#  'плата',
#  'контроллер',
#  'рядом',
#  'соответствующий',
#  'разъём',
#  'интерфейс',
#  'автоматический',
#  'управление',
#  'режим',
#  'приёмапередача',
#  'отсутствовать',
#  'микроконтроллер',
#  'подключить',
#  'пин',
#  'дисплейв',
#  'вывод',
#  'информация',
#  'использоваться',
#  'дисплей',
#  'значение',
#  'факт',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найти',
#  'применить',
#  'ваш',
#  'проект',
#  'адрес',
#  'дисплей',
#  'шина',
#  'кнопка',
#  'кнопка',
#  'хитрый',
#  'подключение',
#  'один',
#  'это',
#  'подключение',
#  'позволять',
#  'отслеживать',
#  'нажатие',
#  'кнопка',
#  'определять',
#  'сочетаниесхема',
#  'подключение',
#  'кнопка',
#  'межблочный',
#  'интерфейсконтроллер',
#  'линейка',
#  'содержать',
#  'межблочный',
#  'интерфейс',
#  'полезный',
#  'дополнение',
#  'который',
#  'позволять',
#  'значительно',
#  'расширить',
#  'базовый',
#  'возможность',
#  'качество',
#  'межблочный',
#  'интерфейс',
#  'использоваться',
#  'контактный',
#  'шлейфовый',
#  'соединениениже',
#  'привести',
#  'распиновка',
#  'межблочный',
#  'разъём',
#  'некоторый',
#  'вопрос',
#  'вызывать',
#  'пина',
#  'вопервое',
#  'назначение',
#  'соответствовать',
#  'различный',
#  'серия',
#  'вовторое',
#  'согласно',
#  'официальный',
#  'документация',
#  'вообще',
#  'подключить',
#  'знать',
#  'качество',
#  'документация',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодный',
#  'индикаторысветодиодный',
#  'индикатор',
#  'состояние',
#  'вход',
#  'шт',
#  'светодиод',
#  'наличие',
#  'напряжение',
#  'питание',
#  'фото',
#  'видно',
#  'светодиод',
#  'цифровой',
#  'выход',
#  'распаять',
#  'распиновкараспиновка',
#  'контроллер',
#  'жёлтый',
#  'цвет',
#  'пометить',
#  'контакт',
#  'вывести',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'остаться',
#  'незадействованный',
#  'быть',
#  'использоваться',
#  'старший',
#  'модель',
#  'серия',
#  'больший',
#  'количество',
#  'подключить',
#  'компонент',
#  'заключений',
#  'качество',
#  'заключение',
#  'сказать',
#  'это',
#  'довольно',
#  'интересный',
#  'модель',
#  'микроконтроллер',
#  'наличие',
#  'модуль',
#  'значительно',
#  'расширять',
#  'её',
#  'возможность',
#  'создание',
#  'проект',
#  'стоить',
#  'также',
#  'отметить',
#  'модель',
#  'иметь',
#  'разъём',
#  'подключение',
#  'дополнительный',
#  'блок',
#  'позволять',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решение',
#  'её',
#  'основа']

# %%
import string
import re
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
def remove_punctuation(text):
    return ''.join([ch for ch in text if ch not in string.punctuation])

def remove_notalpha(text):
    return ''.join([i if i.isalpha() else ' ' for i in text])

def remove_space(text):
    return re.sub(r'\s+',' ', text, flags=re.I)

def remove_latin(text):
    return re.sub('[a-z]','', text, flags=re.I)

def tokenize(text):
    t = word_tokenize(text)
    return [token for token in t if token not in stopword]

# %%
df.head()
# Out:
#      namecompany                                     description   rating  \
# 0  Timeweb Cloud  Облачная платформа для разработчиков и бизнеса  1572.77
# 1           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 2  Онлайн Патент                       Ваш личный патентный офис   220.74
# 3           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 4             VK                  Технологии, которые объединяют   568.63
#
#                                             activity date_publish  \
# 0      Веб-разработка, Домены и хостинг, Веб-сервисы   2023-03-27
# 1  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 2                Консалтинг и поддержка, Веб-сервисы   2023-03-27
# 3  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 4  Мобильные технологии, Веб-сервисы, Игры и разв...   2023-03-27
#
#                                         text_article
# 0  В своём блоге я рассмотрел устройство и назнач...
# 1  Автор статьи: Роман КозловРуководитель курса B...
# 2  Рынок биологически активных добавок(БАД) с каж...
# 3  Автор статьи: Александр КолесниковВирусный ана...
# 4  Всем привет! Меня зовут Артём Пузанков, я DevS...

# %%
prep_text = [tokenize(remove_space(remove_latin(remove_notalpha(remove_punctuation(text.lower()))))) for text in df['text_article'] ]

# %%
df['prep_text'] = prep_text

# %%
prep_text2 = [lemmatize(tokenize(remove_space(remove_latin(remove_notalpha(remove_punctuation(text.lower())))))) for text in df['text_article'] ]

# %%
df['prep_text2'] = prep_text2

# %%
df.head()
# Out:
#      namecompany                                     description   rating  \
# 0  Timeweb Cloud  Облачная платформа для разработчиков и бизнеса  1572.77
# 1           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 2  Онлайн Патент                       Ваш личный патентный офис   220.74
# 3           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 4             VK                  Технологии, которые объединяют   568.63
#
#                                             activity date_publish  \
# 0      Веб-разработка, Домены и хостинг, Веб-сервисы   2023-03-27
# 1  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 2                Консалтинг и поддержка, Веб-сервисы   2023-03-27
# 3  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 4  Мобильные технологии, Веб-сервисы, Игры и разв...   2023-03-27
#
#                                         text_article  \
# 0  В своём блоге я рассмотрел устройство и назнач...
# 1  Автор статьи: Роман КозловРуководитель курса B...
# 2  Рынок биологически активных добавок(БАД) с каж...
# 3  Автор статьи: Александр КолесниковВирусный ана...
# 4  Всем привет! Меня зовут Артём Пузанков, я DevS...
#
#                                            prep_text  \
# 0  [своём, блоге, рассмотрел, устройство, назначе...
# 1  [автор, статьи, роман, козловруководитель, кур...
# 2  [рынок, биологически, активных, добавокбад, ка...
# 3  [автор, статьи, александр, колесниковвирусный,...
# 4  [всем, привет, зовут, артём, пузанков, инженер...
#
#                                           prep_text2
# 0  [свой, блог, рассмотреть, устройство, назначен...
# 1  [автор, статья, роман, козловруководитель, кур...
# 2  [рынок, биологически, активный, добавокбад, ка...
# 3  [автор, статья, александр, колесниковвирусный,...
# 4  [весь, привет, звать, артём, пузанок, инженер,...

# %%
len(df["prep_text2"][0])
# Out:
# 887

# %%
df["prep_text2"][0]
# Out:
# ['свой',
#  'блог',
#  'рассмотреть',
#  'устройство',
#  'назначение',
#  'контроллер',
#  'обойти',
#  'внимание',
#  'оказаться',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'соответствующий',
#  'модуль',
#  'свой',
#  'бортукак',
#  'понимать',
#  'наличие',
#  'модуль',
#  'являться',
#  'существенный',
#  'дополнение',
#  'значительно',
#  'расширять',
#  'возможность',
#  'контроллер',
#  'посылать',
#  'принимать',
#  'информационный',
#  'управлять',
#  'организовать',
#  'резервный',
#  'независимый',
#  'ваш',
#  'инфраструктура',
#  'канал',
#  'связь',
#  'так',
#  'дв',
#  'статья',
#  'рассмотреть',
#  'модель',
#  'который',
#  'кроме',
#  'модуль',
#  'содержать',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'интерфейс',
#  'прочий',
#  'возможность',
#  'делать',
#  'контроллер',
#  'интересный',
#  'решение',
#  'создание',
#  'ваш',
#  'проект',
#  'автоматизация',
#  'семейство',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'качество',
#  'ядро',
#  'модуль',
#  'мб',
#  'так',
#  'далее',
#  'позволять',
#  'решать',
#  'довольно',
#  'тяжёлый',
#  'вычислительный',
#  'задача',
#  'поддерживать',
#  'беспроводный',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрование',
#  'данные',
#  'так',
#  'дбольшинство',
#  'модель',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'модуль',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панель',
#  'корпус',
#  'межблочный',
#  'интерфейс',
#  'цифровой',
#  'опторазвязать',
#  'вход',
#  'остальной',
#  'характеристика',
#  'отличаться',
#  'составить',
#  'представление',
#  'следующий',
#  'таблицемодель',
#  'иметься',
#  'мой',
#  'распоряжение',
#  'выделить',
#  'серый',
#  'фономть',
#  'мой',
#  'распоряжение',
#  'иметься',
#  'начальный',
#  'довольно',
#  'функциональный',
#  'модель',
#  'судить',
#  'вышеприведённый',
#  'таблица',
#  'взять',
#  'официальный',
#  'документация',
#  'этот',
#  'модель',
#  'должный',
#  'иметь',
#  'транзисторный',
#  'выход',
#  'сам',
#  'дело',
#  'отсутствовать',
#  'реальный',
#  'контроллер',
#  'это',
#  'ошибка',
#  'документация',
#  'выход',
#  'просто',
#  'забыть',
#  'распаять',
#  'плата',
#  'сказать',
#  'трудно',
#  'судить',
#  'отсутствие',
#  'маркировка',
#  'выход',
#  'корпус',
#  'устройство',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллер',
#  'линейка',
#  'содержать',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинуть',
#  'модуль',
#  'мой',
#  'случай',
#  'это',
#  'привычный',
#  'мы',
#  'штыревой',
#  'антенна',
#  'корпус',
#  'это',
#  'антенна',
#  'модуль',
#  'компонент',
#  'характеристикич',
#  'порадовать',
#  'давать',
#  'познакомиться',
#  'список',
#  'компонент',
#  'находиться',
#  'борт',
#  'контроллер',
#  'модуль',
#  'внешний',
#  'антеннаразъём',
#  'карта',
#  'цифровой',
#  'вход',
#  'светодиод',
#  'вход',
#  'аналоговый',
#  'вход',
#  'винтерфейс',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличие',
#  'питаниянапряжение',
#  'питание',
#  'век',
#  'целое',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничный',
#  'сбалансированный',
#  'модель',
#  'несложный',
#  'проект',
#  'борт',
#  'присутствовать',
#  'транзисторный',
#  'выход',
#  'заявить',
#  'документация',
#  'всё',
#  'хорошоно',
#  'учитывать',
#  'иметь',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллер',
#  'значительно',
#  'расширить',
#  'соответствие',
#  'требование',
#  'ваш',
#  'проектакартина',
#  'дополнять',
#  'традиционный',
#  'отличный',
#  'дизайн',
#  'корпус',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'светодиодный',
#  'индикатор',
#  'такой',
#  'контроллер',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортить',
#  'внешний',
#  'вид',
#  'ваш',
#  'щиток',
#  'автоматика',
#  'разбирать',
#  'контроллербыть',
#  'контроллер',
#  'один',
#  'неприятный',
#  'родовой',
#  'черта',
#  'практически',
#  'модель',
#  'редкий',
#  'исключение',
#  'очень',
#  'трудно',
#  'разбираться',
#  'сказать',
#  'вообще',
#  'предназначить',
#  'разборка',
#  'процесс',
#  'вскрытие',
#  'корпус',
#  'извлечение',
#  'контроллер',
#  'приходиться',
#  'сильно',
#  'гнуть',
#  'пластмасса',
#  'рисковать',
#  'её',
#  'сломать',
#  'подвергать',
#  'механический',
#  'нагрузка',
#  'сам',
#  'плата',
#  'контроллерапричь',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делать',
#  'точно',
#  'знать',
#  'делать',
#  'например',
#  'время',
#  'разборка',
#  'извлечение',
#  'плата',
#  'поддон',
#  'я',
#  'повредить',
#  'печатный',
#  'дорожка',
#  'край',
#  'плата',
#  'выбор',
#  'большой',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмасса',
#  'корпус',
#  'либо',
#  'риск',
#  'повредить',
#  'плата',
#  'контроллераа',
#  'существовать',
#  'множество',
#  'контроллер',
#  'который',
#  'разбираться',
#  'легко',
#  'простов',
#  'случай',
#  'контроллер',
#  'главный',
#  'виновник',
#  'проблема',
#  'разборка',
#  'сборка',
#  'являться',
#  'боков',
#  'разъём',
#  'расширение',
#  'слишком',
#  'мощный',
#  'фиксатор',
#  'плата',
#  'нижний',
#  'крышка',
#  'корпус',
#  'схемотехникавнутренный',
#  'устройство',
#  'также',
#  'типично',
#  'контроллер',
#  'это',
#  'всё',
#  'тот',
#  'два',
#  'плата',
#  'соединить',
#  'себя',
#  'два',
#  'стойка',
#  'штырёк',
#  'соединение',
#  'неразъёмный',
#  'захотеться',
#  'модернизировать',
#  'значительный',
#  'усилие',
#  'хирургический',
#  'вмешательство',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзор',
#  'обзор',
#  'вынудить',
#  'упоминать',
#  'ещё',
#  'один',
#  'родовой',
#  'проблема',
#  'качество',
#  'её',
#  'документация',
#  'этот',
#  'документация',
#  'просто',
#  'ужасный',
#  'один',
#  'её',
#  'часть',
#  'противоречить',
#  'другой',
#  'документация',
#  'противоречить',
#  'надпись',
#  'корпус',
#  'контроллер',
#  'вместе',
#  'противоречить',
#  'тот',
#  'реально',
#  'железа',
#  'удивительно',
#  'сам',
#  'железо',
#  'вполне',
#  'адекватный',
#  'нормально',
#  'работаетвсе',
#  'дать',
#  'компонент',
#  'контакт',
#  'распиновка',
#  'так',
#  'далее',
#  'обзор',
#  'приходиться',
#  'проверять',
#  'перепроверять',
#  'лупа',
#  'тестер',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основание',
#  'данные',
#  'официальный',
#  'документация',
#  'категорически',
#  'рекомендоваться',
#  'пользоваться',
#  'проверить',
#  'информация',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контакт',
#  'расположение',
#  'индикатор',
#  'модификация',
#  'плата',
#  'контроллераплата',
#  'контроллер',
#  'соединить',
#  'себя',
#  'два',
#  'группа',
#  'контакт',
#  'каждый',
#  'группа',
#  'содержать',
#  'контакт',
#  'сам',
#  'контакт',
#  'сделать',
#  'неразъёмный',
#  'разобрать',
#  'контроллер',
#  'выпаивать',
#  'соединять',
#  'плата',
#  'перемычка',
#  'штырёк',
#  'нижний',
#  'плата',
#  'содержать',
#  'колодка',
#  'подключение',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'питание',
#  'контроллер',
#  'также',
#  'разъём',
#  'интерфейс',
#  'плата',
#  'находиться',
#  'электронный',
#  'компонент',
#  'соответствующий',
#  'подсистемверхнять',
#  'плата',
#  'содержать',
#  'микроконтроллер',
#  'модуль',
#  'разъём',
#  'подключение',
#  'карта',
#  'выносной',
#  'антенна',
#  'межблочный',
#  'интерфейс',
#  'подсистема',
#  'чип',
#  'дисплей',
#  'управлять',
#  'кнопка',
#  'индикаторный',
#  'светодиод',
#  'прочий',
#  'элементыпитаниеподсистема',
#  'питание',
#  'состоять',
#  'импульсный',
#  'понижать',
#  'регулятор',
#  'напряжение',
#  'линейный',
#  'регулятор',
#  'контроллер',
#  'рассчитать',
#  'входной',
#  'напряжение',
#  'работать',
#  'малый',
#  'напряжениявид',
#  'элемент',
#  'подсистема',
#  'питание',
#  'индуктивность',
#  'диод',
#  'фильтровать',
#  'конденсатор',
#  'прочий',
#  'элемент',
#  'микросхема',
#  'преобразователь',
#  'спрятаться',
#  'конденсатор',
#  'индуктивность',
#  'формировать',
#  'напряжение',
#  'находиться',
#  'верхний',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъём',
#  'данный',
#  'случай',
#  'плата',
#  'установить',
#  'модуль',
#  'больший',
#  'пиковый',
#  'потребление',
#  'ток',
#  'поэтому',
#  'полноценный',
#  'питание',
#  'контакт',
#  'колодка',
#  'пренебрегатьядро',
#  'качество',
#  'ядро',
#  'контроллер',
#  'использовать',
#  'популярный',
#  'модуль',
#  'который',
#  'располагаться',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'находиться',
#  'линейный',
#  'регулятор',
#  'формировать',
#  'напряжение',
#  'питаниядлить',
#  'подключение',
#  'компьютер',
#  'программирование',
#  'верхний',
#  'плата',
#  'присутствовать',
#  'разъём',
#  'микросхема',
#  'преобразователь',
#  'также',
#  'прочий',
#  'элемент',
#  'кнопка',
#  'корпус',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровый',
#  'входымодель',
#  'иметь',
#  'цифровой',
#  'вход',
#  'подключить',
#  'два',
#  'микросхема',
#  'содержать',
#  'каждый',
#  'оптопара',
#  'возможный',
#  'вариант',
#  'подключение',
#  'плюс',
#  'контакт',
#  'минус',
#  'терминология',
#  'производитель',
#  'аналоговый',
#  'вход',
#  'иметь',
#  'аналоговый',
#  'вход',
#  'реализовать',
#  'помощь',
#  'микросхема',
#  'битный',
#  'аналогоцифровый',
#  'преобразователь',
#  'интерфейсомрасположение',
#  'плата',
#  'подсистема',
#  'аналогоцифровый',
#  'преобразователь',
#  'чип',
#  'распаять',
#  'обратный',
#  'сторона',
#  'плата',
#  'адрес',
#  'шина',
#  'транзисторный',
#  'выходытранзисторный',
#  'выход',
#  'плата',
#  'просто',
#  'вместе',
#  'микросхема',
#  'хотя',
#  'судить',
#  'официальный',
#  'информация',
#  'сайт',
#  'производитель',
#  'должный',
#  'бытьный',
#  'фото',
#  'отметить',
#  'место',
#  'который',
#  'должный',
#  'распаять',
#  'элемент',
#  'подсистема',
#  'транзисторный',
#  'выход',
#  'почемуть',
#  'распаять',
#  'особый',
#  'желание',
#  'элемент',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основный',
#  'фишка',
#  'контроллер',
#  'модуль',
#  'установить',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'вместе',
#  'разъём',
#  'карта',
#  'внешний',
#  'антенныпро',
#  'работа',
#  'подсистема',
#  'пока',
#  'мочь',
#  'сказать',
#  'определённый',
#  'кроме',
#  'модуль',
#  'отзываться',
#  'команда',
#  'первый',
#  'приближение',
#  'вести',
#  'нормально',
#  'ожидаться',
#  'скорее',
#  'подсистема',
#  'никакой',
#  'проблема',
#  'это',
#  'показать',
#  'дальнейший',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализовать',
#  'типовой',
#  'контроллер',
#  'схема',
#  'чип',
#  'трансивер',
#  'микросхема',
#  'располагаться',
#  'нижний',
#  'плата',
#  'контроллер',
#  'рядом',
#  'соответствующий',
#  'разъём',
#  'интерфейс',
#  'автоматический',
#  'управление',
#  'режим',
#  'приёмапередача',
#  'отсутствовать',
#  'микроконтроллер',
#  'подключить',
#  'пин',
#  'дисплейв',
#  'вывод',
#  'информация',
#  'использоваться',
#  'дисплей',
#  'значение',
#  'факт',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найти',
#  'применить',
#  'ваш',
#  'проект',
#  'адрес',
#  'дисплей',
#  'шина',
#  'кнопка',
#  'кнопка',
#  'хитрый',
#  'подключение',
#  'один',
#  'это',
#  'подключение',
#  'позволять',
#  'отслеживать',
#  'нажатие',
#  'кнопка',
#  'определять',
#  'сочетаниесхема',
#  'подключение',
#  'кнопка',
#  'межблочный',
#  'интерфейсконтроллер',
#  'линейка',
#  'содержать',
#  'межблочный',
#  'интерфейс',
#  'полезный',
#  'дополнение',
#  'который',
#  'позволять',
#  'значительно',
#  'расширить',
#  'базовый',
#  'возможность',
#  'качество',
#  'межблочный',
#  'интерфейс',
#  'использоваться',
#  'контактный',
#  'шлейфовый',
#  'соединениениже',
#  'привести',
#  'распиновка',
#  'межблочный',
#  'разъём',
#  'некоторый',
#  'вопрос',
#  'вызывать',
#  'пина',
#  'вопервое',
#  'назначение',
#  'соответствовать',
#  'различный',
#  'серия',
#  'вовторое',
#  'согласно',
#  'официальный',
#  'документация',
#  'вообще',
#  'подключить',
#  'знать',
#  'качество',
#  'документация',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодный',
#  'индикаторысветодиодный',
#  'индикатор',
#  'состояние',
#  'вход',
#  'шт',
#  'светодиод',
#  'наличие',
#  'напряжение',
#  'питание',
#  'фото',
#  'видно',
#  'светодиод',
#  'цифровой',
#  'выход',
#  'распаять',
#  'распиновкараспиновка',
#  'контроллер',
#  'жёлтый',
#  'цвет',
#  'пометить',
#  'контакт',
#  'вывести',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'остаться',
#  'незадействованный',
#  'быть',
#  'использоваться',
#  'старший',
#  'модель',
#  'серия',
#  'больший',
#  'количество',
#  'подключить',
#  'компонент',
#  'заключений',
#  'качество',
#  'заключение',
#  'сказать',
#  'это',
#  'довольно',
#  'интересный',
#  'модель',
#  'микроконтроллер',
#  'наличие',
#  'модуль',
#  'значительно',
#  'расширять',
#  'её',
#  'возможность',
#  'создание',
#  'проект',
#  'стоить',
#  'также',
#  'отметить',
#  'модель',
#  'иметь',
#  'разъём',
#  'подключение',
#  'дополнительный',
#  'блок',
#  'позволять',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решение',
#  'её',
#  'основа']

# %%
tt = remove_stopwords(df["prep_text2"][0])

# %%
len(tt)
# Out:
# 857

# %%
tt
# Out:
# ['свой',
#  'блог',
#  'рассмотреть',
#  'устройство',
#  'назначение',
#  'контроллер',
#  'обойти',
#  'внимание',
#  'оказаться',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'соответствующий',
#  'модуль',
#  'свой',
#  'бортукак',
#  'понимать',
#  'наличие',
#  'модуль',
#  'являться',
#  'существенный',
#  'дополнение',
#  'значительно',
#  'расширять',
#  'возможность',
#  'контроллер',
#  'посылать',
#  'принимать',
#  'информационный',
#  'управлять',
#  'организовать',
#  'резервный',
#  'независимый',
#  'ваш',
#  'инфраструктура',
#  'канал',
#  'связь',
#  'дв',
#  'статья',
#  'рассмотреть',
#  'модель',
#  'который',
#  'кроме',
#  'модуль',
#  'содержать',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'интерфейс',
#  'прочий',
#  'возможность',
#  'делать',
#  'контроллер',
#  'интересный',
#  'решение',
#  'создание',
#  'ваш',
#  'проект',
#  'автоматизация',
#  'семейство',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'качество',
#  'ядро',
#  'модуль',
#  'мб',
#  'далее',
#  'позволять',
#  'решать',
#  'довольно',
#  'тяжёлый',
#  'вычислительный',
#  'задача',
#  'поддерживать',
#  'беспроводный',
#  'связь',
#  'полноценный',
#  'вебинтерфейс',
#  'работать',
#  'шифрование',
#  'данные',
#  'дбольшинство',
#  'модель',
#  'контроллер',
#  'линейка',
#  'иметь',
#  'модуль',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панель',
#  'корпус',
#  'межблочный',
#  'интерфейс',
#  'цифровой',
#  'опторазвязать',
#  'вход',
#  'остальной',
#  'характеристика',
#  'отличаться',
#  'составить',
#  'представление',
#  'следующий',
#  'таблицемодель',
#  'иметься',
#  'распоряжение',
#  'выделить',
#  'серый',
#  'фономть',
#  'распоряжение',
#  'иметься',
#  'начальный',
#  'довольно',
#  'функциональный',
#  'модель',
#  'судить',
#  'вышеприведённый',
#  'таблица',
#  'взять',
#  'официальный',
#  'документация',
#  'модель',
#  'должный',
#  'иметь',
#  'транзисторный',
#  'выход',
#  'дело',
#  'отсутствовать',
#  'реальный',
#  'контроллер',
#  'это',
#  'ошибка',
#  'документация',
#  'выход',
#  'просто',
#  'забыть',
#  'распаять',
#  'плата',
#  'сказать',
#  'трудно',
#  'судить',
#  'отсутствие',
#  'маркировка',
#  'выход',
#  'корпус',
#  'устройство',
#  'это',
#  'скорее',
#  'ошибка',
#  'документациивсе',
#  'контроллер',
#  'линейка',
#  'содержать',
#  'модуль',
#  'это',
#  'либо',
#  'простой',
#  'либо',
#  'продвинуть',
#  'модуль',
#  'случай',
#  'это',
#  'привычный',
#  'штыревой',
#  'антенна',
#  'корпус',
#  'это',
#  'антенна',
#  'модуль',
#  'компонент',
#  'характеристикич',
#  'порадовать',
#  'давать',
#  'познакомиться',
#  'список',
#  'компонент',
#  'находиться',
#  'борт',
#  'контроллер',
#  'модуль',
#  'внешний',
#  'антеннаразъём',
#  'карта',
#  'цифровой',
#  'вход',
#  'светодиод',
#  'вход',
#  'аналоговый',
#  'вход',
#  'винтерфейс',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'передний',
#  'панелимежблочный',
#  'интерфейс',
#  'разъём',
#  'программированиякнопка',
#  'индикатор',
#  'наличие',
#  'питаниянапряжение',
#  'питание',
#  'век',
#  'целое',
#  'сказать',
#  'это',
#  'довольно',
#  'гармоничный',
#  'сбалансированный',
#  'модель',
#  'несложный',
#  'проект',
#  'борт',
#  'присутствовать',
#  'транзисторный',
#  'выход',
#  'заявить',
#  'документация',
#  'всё',
#  'хорошоно',
#  'учитывать',
#  'иметь',
#  'межблочный',
#  'интерфейс',
#  'функционал',
#  'контроллер',
#  'значительно',
#  'расширить',
#  'соответствие',
#  'требование',
#  'ваш',
#  'проектакартина',
#  'дополнять',
#  'традиционный',
#  'отличный',
#  'дизайн',
#  'корпус',
#  'дисплей',
#  'кнопка',
#  'управление',
#  'светодиодный',
#  'индикатор',
#  'контроллер',
#  'очень',
#  'приятно',
#  'работать',
#  'точно',
#  'испортить',
#  'внешний',
#  'вид',
#  'ваш',
#  'щиток',
#  'автоматика',
#  'разбирать',
#  'контроллербыть',
#  'контроллер',
#  'неприятный',
#  'родовой',
#  'черта',
#  'практически',
#  'модель',
#  'редкий',
#  'исключение',
#  'очень',
#  'трудно',
#  'разбираться',
#  'сказать',
#  'вообще',
#  'предназначить',
#  'разборка',
#  'процесс',
#  'вскрытие',
#  'корпус',
#  'извлечение',
#  'контроллер',
#  'приходиться',
#  'сильно',
#  'гнуть',
#  'пластмасса',
#  'рисковать',
#  'её',
#  'сломать',
#  'подвергать',
#  'механический',
#  'нагрузка',
#  'плата',
#  'контроллерапричь',
#  'разобрать',
#  'контроллер',
#  'трудно',
#  'это',
#  'делать',
#  'точно',
#  'знать',
#  'делать',
#  'например',
#  'время',
#  'разборка',
#  'извлечение',
#  'плата',
#  'поддон',
#  'повредить',
#  'печатный',
#  'дорожка',
#  'край',
#  'плата',
#  'выбор',
#  'большой',
#  'либо',
#  'риск',
#  'сломать',
#  'пластмасса',
#  'корпус',
#  'либо',
#  'риск',
#  'повредить',
#  'плата',
#  'контроллераа',
#  'существовать',
#  'множество',
#  'контроллер',
#  'который',
#  'разбираться',
#  'легко',
#  'простов',
#  'случай',
#  'контроллер',
#  'главный',
#  'виновник',
#  'проблема',
#  'разборка',
#  'сборка',
#  'являться',
#  'боков',
#  'разъём',
#  'расширение',
#  'слишком',
#  'мощный',
#  'фиксатор',
#  'плата',
#  'нижний',
#  'крышка',
#  'корпус',
#  'схемотехникавнутренный',
#  'устройство',
#  'также',
#  'типично',
#  'контроллер',
#  'это',
#  'всё',
#  'плата',
#  'соединить',
#  'стойка',
#  'штырёк',
#  'соединение',
#  'неразъёмный',
#  'захотеться',
#  'модернизировать',
#  'значительный',
#  'усилие',
#  'хирургический',
#  'вмешательство',
#  'это',
#  'сделать',
#  'получитсяахтунг',
#  'обзор',
#  'обзор',
#  'вынудить',
#  'упоминать',
#  'ещё',
#  'родовой',
#  'проблема',
#  'качество',
#  'её',
#  'документация',
#  'документация',
#  'просто',
#  'ужасный',
#  'её',
#  'часть',
#  'противоречить',
#  'документация',
#  'противоречить',
#  'надпись',
#  'корпус',
#  'контроллер',
#  'вместе',
#  'противоречить',
#  'реально',
#  'железа',
#  'удивительно',
#  'железо',
#  'вполне',
#  'адекватный',
#  'нормально',
#  'работаетвсе',
#  'дать',
#  'компонент',
#  'контакт',
#  'распиновка',
#  'далее',
#  'обзор',
#  'приходиться',
#  'проверять',
#  'перепроверять',
#  'лупа',
#  'тестер',
#  'поэтому',
#  'чтолибо',
#  'подключать',
#  'основание',
#  'данные',
#  'официальный',
#  'документация',
#  'категорически',
#  'рекомендоваться',
#  'пользоваться',
#  'проверить',
#  'информация',
#  'статьивнешний',
#  'вид',
#  'назначение',
#  'контакт',
#  'расположение',
#  'индикатор',
#  'модификация',
#  'плата',
#  'контроллераплата',
#  'контроллер',
#  'соединить',
#  'группа',
#  'контакт',
#  'каждый',
#  'группа',
#  'содержать',
#  'контакт',
#  'контакт',
#  'сделать',
#  'неразъёмный',
#  'разобрать',
#  'контроллер',
#  'выпаивать',
#  'соединять',
#  'плата',
#  'перемычка',
#  'штырёк',
#  'нижний',
#  'плата',
#  'содержать',
#  'колодка',
#  'подключение',
#  'цифровой',
#  'аналоговый',
#  'вход',
#  'питание',
#  'контроллер',
#  'также',
#  'разъём',
#  'интерфейс',
#  'плата',
#  'находиться',
#  'электронный',
#  'компонент',
#  'соответствующий',
#  'подсистемверхнять',
#  'плата',
#  'содержать',
#  'микроконтроллер',
#  'модуль',
#  'разъём',
#  'подключение',
#  'карта',
#  'выносной',
#  'антенна',
#  'межблочный',
#  'интерфейс',
#  'подсистема',
#  'чип',
#  'дисплей',
#  'управлять',
#  'кнопка',
#  'индикаторный',
#  'светодиод',
#  'прочий',
#  'элементыпитаниеподсистема',
#  'питание',
#  'состоять',
#  'импульсный',
#  'понижать',
#  'регулятор',
#  'напряжение',
#  'линейный',
#  'регулятор',
#  'контроллер',
#  'рассчитать',
#  'входной',
#  'напряжение',
#  'работать',
#  'малый',
#  'напряжениявид',
#  'элемент',
#  'подсистема',
#  'питание',
#  'индуктивность',
#  'диод',
#  'фильтровать',
#  'конденсатор',
#  'прочий',
#  'элемент',
#  'микросхема',
#  'преобразователь',
#  'спрятаться',
#  'конденсатор',
#  'индуктивность',
#  'формировать',
#  'напряжение',
#  'находиться',
#  'верхний',
#  'платечастично',
#  'запитать',
#  'контроллер',
#  'разъём',
#  'данный',
#  'случай',
#  'плата',
#  'установить',
#  'модуль',
#  'больший',
#  'пиковый',
#  'потребление',
#  'ток',
#  'поэтому',
#  'полноценный',
#  'питание',
#  'контакт',
#  'колодка',
#  'пренебрегатьядро',
#  'качество',
#  'ядро',
#  'контроллер',
#  'использовать',
#  'популярный',
#  'модуль',
#  'который',
#  'располагаться',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'находиться',
#  'линейный',
#  'регулятор',
#  'формировать',
#  'напряжение',
#  'питаниядлить',
#  'подключение',
#  'компьютер',
#  'программирование',
#  'верхний',
#  'плата',
#  'присутствовать',
#  'разъём',
#  'микросхема',
#  'преобразователь',
#  'также',
#  'прочий',
#  'элемент',
#  'кнопка',
#  'корпус',
#  'рядом',
#  'разъём',
#  'отверстие',
#  'её',
#  'нажатияцифровый',
#  'входымодель',
#  'иметь',
#  'цифровой',
#  'вход',
#  'подключить',
#  'микросхема',
#  'содержать',
#  'каждый',
#  'оптопара',
#  'возможный',
#  'вариант',
#  'подключение',
#  'плюс',
#  'контакт',
#  'минус',
#  'терминология',
#  'производитель',
#  'аналоговый',
#  'вход',
#  'иметь',
#  'аналоговый',
#  'вход',
#  'реализовать',
#  'помощь',
#  'микросхема',
#  'битный',
#  'аналогоцифровый',
#  'преобразователь',
#  'интерфейсомрасположение',
#  'плата',
#  'подсистема',
#  'аналогоцифровый',
#  'преобразователь',
#  'чип',
#  'распаять',
#  'обратный',
#  'сторона',
#  'плата',
#  'адрес',
#  'шина',
#  'транзисторный',
#  'выходытранзисторный',
#  'выход',
#  'плата',
#  'просто',
#  'вместе',
#  'микросхема',
#  'хотя',
#  'судить',
#  'официальный',
#  'информация',
#  'сайт',
#  'производитель',
#  'должный',
#  'бытьный',
#  'фото',
#  'отметить',
#  'место',
#  'который',
#  'должный',
#  'распаять',
#  'элемент',
#  'подсистема',
#  'транзисторный',
#  'выход',
#  'почемуть',
#  'распаять',
#  'особый',
#  'желание',
#  'элемент',
#  'допаять',
#  'самостоятельно',
#  'модуль',
#  'основный',
#  'фишка',
#  'контроллер',
#  'модуль',
#  'установить',
#  'обратный',
#  'сторона',
#  'верхний',
#  'плата',
#  'вместе',
#  'разъём',
#  'карта',
#  'внешний',
#  'антенныпро',
#  'работа',
#  'подсистема',
#  'пока',
#  'мочь',
#  'сказать',
#  'определённый',
#  'кроме',
#  'модуль',
#  'отзываться',
#  'команда',
#  'первый',
#  'приближение',
#  'вести',
#  'нормально',
#  'ожидаться',
#  'скорее',
#  'подсистема',
#  'никакой',
#  'проблема',
#  'это',
#  'показать',
#  'дальнейший',
#  'тестыинтерфейс',
#  'интерфейс',
#  'реализовать',
#  'типовой',
#  'контроллер',
#  'схема',
#  'чип',
#  'трансивер',
#  'микросхема',
#  'располагаться',
#  'нижний',
#  'плата',
#  'контроллер',
#  'рядом',
#  'соответствующий',
#  'разъём',
#  'интерфейс',
#  'автоматический',
#  'управление',
#  'режим',
#  'приёмапередача',
#  'отсутствовать',
#  'микроконтроллер',
#  'подключить',
#  'пин',
#  'дисплейв',
#  'вывод',
#  'информация',
#  'использоваться',
#  'дисплей',
#  'значение',
#  'факт',
#  'трудно',
#  'переоценить',
#  'точно',
#  'найти',
#  'применить',
#  'ваш',
#  'проект',
#  'адрес',
#  'дисплей',
#  'шина',
#  'кнопка',
#  'кнопка',
#  'хитрый',
#  'подключение',
#  'это',
#  'подключение',
#  'позволять',
#  'отслеживать',
#  'нажатие',
#  'кнопка',
#  'определять',
#  'сочетаниесхема',
#  'подключение',
#  'кнопка',
#  'межблочный',
#  'интерфейсконтроллер',
#  'линейка',
#  'содержать',
#  'межблочный',
#  'интерфейс',
#  'полезный',
#  'дополнение',
#  'который',
#  'позволять',
#  'значительно',
#  'расширить',
#  'базовый',
#  'возможность',
#  'качество',
#  'межблочный',
#  'интерфейс',
#  'использоваться',
#  'контактный',
#  'шлейфовый',
#  'соединениениже',
#  'привести',
#  'распиновка',
#  'межблочный',
#  'разъём',
#  'некоторый',
#  'вопрос',
#  'вызывать',
#  'пина',
#  'вопервое',
#  'назначение',
#  'соответствовать',
#  'различный',
#  'серия',
#  'вовторое',
#  'согласно',
#  'официальный',
#  'документация',
#  'вообще',
#  'подключить',
#  'знать',
#  'качество',
#  'документация',
#  'это',
#  'нужно',
#  'проверять',
#  'отдельносветодиодный',
#  'индикаторысветодиодный',
#  'индикатор',
#  'состояние',
#  'вход',
#  'шт',
#  'светодиод',
#  'наличие',
#  'напряжение',
#  'питание',
#  'фото',
#  'видно',
#  'светодиод',
#  'цифровой',
#  'выход',
#  'распаять',
#  'распиновкараспиновка',
#  'контроллер',
#  'жёлтый',
#  'цвет',
#  'пометить',
#  'контакт',
#  'вывести',
#  'межблочный',
#  'разъём',
#  'видно',
#  'множество',
#  'остаться',
#  'незадействованный',
#  'использоваться',
#  'старший',
#  'модель',
#  'серия',
#  'больший',
#  'количество',
#  'подключить',
#  'компонент',
#  'заключений',
#  'качество',
#  'заключение',
#  'сказать',
#  'это',
#  'довольно',
#  'интересный',
#  'модель',
#  'микроконтроллер',
#  'наличие',
#  'модуль',
#  'значительно',
#  'расширять',
#  'её',
#  'возможность',
#  'создание',
#  'проект',
#  'стоить',
#  'также',
#  'отметить',
#  'модель',
#  'иметь',
#  'разъём',
#  'подключение',
#  'дополнительный',
#  'блок',
#  'позволять',
#  'ещё',
#  'расширить',
#  'диапазон',
#  'решение',
#  'её',
#  'основа']

# %%
stopword.extend(['либо', 'это', 'мб', 'далее', 'дв', 'свой', 'ваш','всё', 'очень', 'её', 'ещё', 'вообще'])

# %%
tt = remove_stopwords(df["prep_text2"][0])

# %%
len(tt)
# Out:
# 815

# %%
# %%time
prep_text3 = prep_text2 = [remove_stopwords(lemmatize(tokenize(remove_space(remove_latin(remove_notalpha(remove_punctuation(text.lower()))))))) for text in df['text_article'] ]
# Out:
# Wall time: 1min 6s

# %%
df['prep_text2'] = prep_text3

# %%
df.head()
# Out:
#      namecompany                                     description   rating  \
# 0  Timeweb Cloud  Облачная платформа для разработчиков и бизнеса  1572.77
# 1           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 2  Онлайн Патент                       Ваш личный патентный офис   220.74
# 3           OTUS            Цифровые навыки от ведущих экспертов   795.43
# 4             VK                  Технологии, которые объединяют   568.63
#
#                                             activity date_publish  \
# 0      Веб-разработка, Домены и хостинг, Веб-сервисы   2023-03-27
# 1  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 2                Консалтинг и поддержка, Веб-сервисы   2023-03-27
# 3  Консалтинг и поддержка, Рекрутинг и HR, Произв...   2023-03-27
# 4  Мобильные технологии, Веб-сервисы, Игры и разв...   2023-03-27
#
#                                         text_article  \
# 0  В своём блоге я рассмотрел устройство и назнач...
# 1  Автор статьи: Роман КозловРуководитель курса B...
# 2  Рынок биологически активных добавок(БАД) с каж...
# 3  Автор статьи: Александр КолесниковВирусный ана...
# 4  Всем привет! Меня зовут Артём Пузанков, я DevS...
#
#                                            prep_text  \
# 0  [своём, блоге, рассмотрел, устройство, назначе...
# 1  [автор, статьи, роман, козловруководитель, кур...
# 2  [рынок, биологически, активных, добавокбад, ка...
# 3  [автор, статьи, александр, колесниковвирусный,...
# 4  [всем, привет, зовут, артём, пузанков, инженер...
#
#                                           prep_text2
# 0  [блог, рассмотреть, устройство, назначение, ко...
# 1  [автор, статья, роман, козловруководитель, кур...
# 2  [рынок, биологически, активный, добавокбад, ка...
# 3  [автор, статья, александр, колесниковвирусный,...
# 4  [весь, привет, звать, артём, пузанок, инженер,...
