# %% [markdown]
# ### 1. Import seaborn

# %%
import seaborn as sns

# %% [markdown]
# ### 2. Import pyplot from matplotlib

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### 3. Import pandas for csv file reading

# %%
import pandas as pd

# %% [markdown]
# ### 4. Write the code which allows to show plots in jupiter notebook

# %%
# %matplotlib inline

# %% [markdown]
# ### 5. Create a variable and read data from csv file in it

# %%
df = pd.read_csv("22 german_credit_data.csv")

# %% [markdown]
# ### 6. Show first 10 rows from the dataset

# %%
df.head(10)
# Out:
#    Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0           0   67    male    2     own             NaN           little
# 1           1   22  female    2     own          little         moderate
# 2           2   49    male    1     own          little              NaN
# 3           3   45    male    2    free          little           little
# 4           4   53    male    2    free          little           little
# 5           5   35    male    1    free             NaN              NaN
# 6           6   53    male    2     own      quite rich              NaN
# 7           7   35    male    3    rent          little         moderate
# 8           8   61    male    1     own            rich              NaN
# 9           9   28    male    3     own          little         moderate
#
#    Credit amount  Duration              Purpose
# 0           1169         6             radio/TV
# 1           5951        48             radio/TV
# 2           2096        12            education
# 3           7882        42  furniture/equipment
# 4           4870        24                  car
# 5           9055        36            education
# 6           2835        24  furniture/equipment
# 7           6948        36                  car
# 8           3059        12             radio/TV
# 9           5234        30                  car

# %% [markdown]
# ### 7. Try to recreate the plot from image below

# %%
sns.jointplot(data=df, x='Age', y='Credit amount')

# %% [markdown]
# ### 8. Try to recreate the plot from image below

# %%
sns.displot(df['Duration'])

# %% [markdown]
# ### 9. Try to recreate the plot from image below

# %%
sns.boxplot(data=df, x='Housing', y='Age')
# Out:
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 10. Try to recreate the plot from image below

# %%
sns.swarmplot( data=df, x='Housing', y='Age')
# Out:
# C:\Users\nudan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\Users\nudan\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 13.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Housing', ylabel='Age'>

# %% [markdown]
# ### 11. Try to recreate the plot from image below

# %%
sns.countplot(data=df, x='Sex')
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='count'>

# %% [markdown]
# ### 12. Try to recreate the plot from image below

# %%
df_corr = df.corr()
sns.heatmap(df_corr)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 13. Try to recreate the plot from image below

# %%
grid = sns.FacetGrid(data=df, col='Housing')
grid.map(sns.histplot, 'Credit amount')
