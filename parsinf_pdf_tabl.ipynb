# %%
import tabula 
import pandas as pd
import glob
import os
import numpy as np

# %%
os.chdir("D:\ДопЗадания\Data\Технические описания компетенций")
files_pdf = glob.glob("*.pdf")
files_pdf
# Out:
# ['Магистральные линии связи. Строительство и эксплуатация ВОЛП.pdf',
#  'Медицинская оптика.pdf',
#  'Метрология.pdf',
#  'Мехатроника .pdf',
#  'Мобильная робототехника.pdf',
#  'Обработка листового металла.pdf',
#  'Обслуживание грузовой техники.pdf',
#  'Обслуживание и ремонт оборудования релейной защиты и автоматики.pdf',
#  'Огранка ювелирных вставок.pdf',
#  'Организация строительного производства.pdf',
#  'Охрана окружающей среды.pdf',
#  'Охрана труда.pdf',
#  'Плотницкое дело(юниоры).pdf',
#  'Плотницкое дело.pdf',
#  'Полимеханика и автоматизация.pdf',
#  'Правоохранительная деятельность (Полицейский).pdf',
#  'Преподавание музыки в школе.pdf',
#  'Производственная сборка изделий авиационной техники.pdf',
#  'Производство металлоконструкций.pdf',
#  'Промышленный дизайн .pdf',
#  'Сметное дело.pdf',
#  'Спасательные работы.pdf',
#  'Столярное дело.pdf',
#  'Туроператорская деятельность.pdf',
#  'Укладка напольных покрытий.pdf',
#  'Управление локомотивом.pdf',
# ...

# %%
tables = tabula.read_pdf(files_pdf[1], 
                         pages="all", 
                         multiple_tables=True, 
                         lattice=False,
                         area=(0, 0, 1000, 1000), 
                         columns=[200, 265, 300, 320], 
                         pandas_options={'header': None}, 
                         stream=True)

# %%
for table in tables: 
    display(table)
# Out:
#       0     1    2    3          4
# 0   NaN   NaN  NaN  NaN        NaN
# 1   NaN   NaN  NaN  NaN        NaN
# 2  ТЕХН  ИЧЕС   КО    Е        NaN
# 3  ОПИС  АНИЕ    К    О  МПЕТЕНЦИИ
# 4     М  едиц  инс    к  ая оптика
#                                   0                         1              2  \
# 0                               NaN                       NaN            NaN
# 1                               NaN                       NaN            NaN
# 2                               NaN                       NaN            NaN
# 3                               NaN                       NaN            NaN
# 4               Организация Союз «М                 олодые пр          офесс
# 5               WSR) в соответствии               с уставом о          ргани
# 6              конкурсов установила             нижеизложенны            NaN
# 7               этим профессиональн                 ым навыко          м для
# ...

# %%
start_table = int()
end_table = int()
for i in range(0, len(tables)):
    if tables[i].columns[0] == "Раздел":
        start_table = i
        print(start_table)
        
for i in range(0, len(tables)):
    if tables[i].columns[0] == "Критерий":
        end_table = i -1 
        print(end_table)
# Out:
# 0
# 8

# %%
new_table = tables[start_table].to_numpy()
a= np.array({})
for i in range(start_table +2, end_table, 2):
    if(i != 6):
        new_table = np.vstack([new_table, tables[i].to_numpy()])
#     new_table.add(tables[i].to_numpy())
#     new_table.join(tables[i], as)
#     pd.merge(new_table, tables[i])
#     print(tables[i])
new_table
# Out:
# array([[nan, nan, nan, nan, nan, nan, '%)', nan, nan],
#        [nan, nan, nan, nan,
#         'рганизовывать, планировать и анализировать работу', nan, nan,
#         nan, nan],
#        [nan,
#         'Специалист должен знать и понимать:\r\uf0b7назначение, использование, техническое\rобслуживание и уход за  оборудованием, а также\rбезопасность его применения;\r•\rосновы информатики и вычислительной техники;\r•\rметоды поиска для получения соответствующей\rинформации специального и общего характера,\rтехнических условий и инструкций;\r•\rвнутренние организационно-распорядительные\rдокументы экономического субъекта,\rрегламентирующие способы защиты персональных\rданных;\r•',
#         nan, nan, nan, nan, nan, nan, nan],
#        [nan,
# ...

# %%
for i in new_table:
    for j in i:
        if(str(j) != "nan"):
           print(j)
# Out:
# %)
# рганизовывать, планировать и анализировать работу
# •анных;нтирующие способы защиты персональныхже
# профессиональных задач.вного выполнениямацию,ых
# рганизовывать сбыт продукции
# на оптические средства коррекции зрения;товки
# переносицы);высота переносицы, ширинартексноея и
# станавливать межличностную коммуникацию
# 12.0
# покупателя очками.еудовлетворенноституации;
# отдельных видов товара.оложения правил продажи
# роводить продажу (или продавать )
# 6.0
# Специалист должен знать и понимать:
# средствами коррекции зрения.а ухода за к ним,
# роводить измерения и контроль параметров
# 47.5
# способы проверки линз на оптических приборах;,
# рассчитывать технологическую возможность;сное
